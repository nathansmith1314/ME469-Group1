# %%
from sympy import *
init_printing()

# %% [markdown]
# Define time variable

# %%
t = Symbol('t')

# %% [markdown]
# Define parameter symbols

# %%
# limb lengths
l_1, l_2, l_3, l_4 = symbols('l_1, l_2, l_3, l_4')

# limb masses
m_1, m_2, m_3 = symbols('m_1, m_2, m_3')

# Hip mass
m_A = symbols('m_A')

# joint stiffnesses
k_B, k_C = symbols('k_B, k_C')

# joint damping
b_B, b_C = symbols('b_B, b_C')

# joint neutral angles
psi_B, psi_C = symbols('psi_B, psi_C')

# foot angle
phi_D = symbols('phi_D')

# Walking speed
v = symbols('v')

# gravity
g = symbols('g')

# Swing phase hip height
y_A_SW = Function('y_ASW')(t)

# %% [markdown]
# Define coordinate symbols

# %%
# limb orientations
theta_1 = Function('theta_1')(t)
theta_2 = Function('theta_2')(t)
theta_3 = Function('theta_3')(t)

# Lagrange multipliers
mu_1 = Function('mu_1')(t)
mu_2 = Function('mu_2')(t)

lamda_1 = Function('lamda_1')
lamda_2 = Function('lamda_2')
lamda_3 = Function('lamda_3')
lamda_4 = Function('lamda_4')

# hip height
y = Function('y')(t)

# %% [markdown]
# Calculate positions

# %%
# rates of change
omega_1 = diff(theta_1)
omega_2 = diff(theta_2)
omega_3 = diff(theta_3)

# heel angle
theta_4 = theta_3 - phi_D
omega_4 = diff(theta_4, t)

# joint positions
x_A = 0
y_A = y
x_B = x_A + l_1 * sin(theta_1)
y_B = y_A - l_1 * cos(theta_1)
x_C = x_B + l_2 * sin(theta_2)
y_C = y_B - l_2 * cos(theta_2)
x_D = x_C + l_3 * sin(theta_3)
y_D = y_C - l_3 * cos(theta_3)
x_E = x_C + l_4 * sin(theta_4)
y_E = y_C - l_4 * cos(theta_4)

# joint velocities
u_A = diff(x_A, t)
v_A = diff(y_A, t)
u_B = diff(x_B, t)
v_B = diff(y_B, t)
u_C = diff(x_C, t)
v_C = diff(y_C, t)
u_D = diff(x_D, t)
v_D = diff(y_D, t)
u_E = diff(x_E, t)
v_E = diff(y_E, t)

# Centers of masses
x_1 = x_A + l_1 * sin(theta_1) / 2
y_1 = y_A - l_1 * cos(theta_1) / 2
x_2 = x_B + l_2 * sin(theta_2) / 2
y_2 = y_B - l_2 * cos(theta_2) / 2
x_3 = x_C + l_3 * sin(theta_3) / 2
y_3 = y_C - l_3 * cos(theta_3) / 2

# COM velocities
u_1 = diff(x_1, t)
v_1 = diff(y_1, t)
u_2 = diff(x_2, t)
v_2 = diff(y_2, t)
u_3 = diff(x_3, t)
v_3 = diff(y_3, t)

# %%
y_B
# Out:
# -l₁⋅cos(θ₁(t)) + y(t)

# %%
# Moments of inertia
I_1 = m_1 * l_1**2 / 12
I_2 = m_2 * l_2**2 / 12
I_3 = m_3 * l_3**2 / 12

# %% [markdown]
# Calculate Lagrangian

# %%
# Kinetic Energy
T = m_1 * (u_1**2 + v_1**2) / 2 + m_2 * (u_2**2 + v_2**2) / 2 + m_3 * (u_3**2 + v_3**2) / 2 + I_1 * omega_1**2 / 2 + I_2 * omega_2**2 / 2 + I_3 * omega_3**2 / 2

# Potential Energy
V = k_B * (theta_1 - theta_2 - psi_B)**2 / 2 + k_C * (theta_2 - theta_3 - psi_C)**2 / 2

# Content
D = b_B * (omega_1 - omega_2)**2 / 2 + b_C * (omega_2 - omega_3)**2 / 2

# %%
## Constraint equations ###

''' Notes: 
    - This is a section to lay out the constraints/define the "regiemes". I am wondering if for our analysis we should pull set this in a 
       for loop? By that I mean should it be have a matrix where time is the top row and we have a row for each theta. At every time interval 
       we have a measured theta. The below constraints then are only active over their "regieme" and apply to the analysis in their specified
       time domain?
    '''

# Swing

'''Notes:
      - This is the stage where the one leg is swinging while the other leg is standing up going through the cycle.
  
  '''

const_SW_y_A = y_A - y_A_SW


# Heel_Strike
'''Notes:
            - This is where heel strike contacts the gorund and jhas the following contraints
                - y_E = 0 
                - u_3 = 0
                - v_3 = 0 
                - y_D = ED*sin(theta3) This is inherent to the system will not be set

                Side: Note, should this be a for loop with a matrix? like for t = .1->.25 then have the HS constraints?
                   '''

const_HS_y_E = y_E
const_HS_u_E = u_E + v


# Foot_Planted

'''Notes:
            - This is where the foot is "pulling" across the ground to push the body forward. As we have restricted Y to the 0,0
              position, the foot will be moving around it.
                - y_E = 0 due to the foot being on the ground
                - y_D = 0 due to the foot being on the gorund
                - v_3 = due to the foot not traveling upward 
                   '''

const_FP_y_E = y_E
const_FP_y_D = y_D
const_FP_u_E = u_E + v
const_FP_u_D = u_D + v

# Toe_Lift_Off
'''Notes:
            - This is where the toe is about to kick off of the ground. 
                - y_D = 0 due to the foot being on the gorund

'''

const_TLO_y_D = y_D
const_TLO_u_D = u_D + v

# %% [markdown]
# Pfaffian Form of Constraints

# %%
const_HS_u_E
# Out:
#               d                         d                               d      ↪
# l₁⋅cos(θ₁(t))⋅──(θ₁(t)) + l₂⋅cos(θ₂(t))⋅──(θ₂(t)) + l₄⋅cos(φ_D - θ₃(t))⋅──(θ₃( ↪
#               dt                        dt                              dt     ↪
#
# ↪
# ↪ t)) + v
# ↪

# %%
const_TLO_u_D
# Out:
#               d                         d                         d
# l₁⋅cos(θ₁(t))⋅──(θ₁(t)) + l₂⋅cos(θ₂(t))⋅──(θ₂(t)) + l₃⋅cos(θ₃(t))⋅──(θ₃(t)) + v
#               dt                        dt                        dt

# %% [markdown]
# Solve constraints for variables

# %%
# Swing
solve(const_SW_y_A, y)[0]
Eq(y, y_A_SW)
# Out:
# y(t) = y_ASW(t)

# %%
# Heel Strike 1, y position
y_HS = solve(const_HS_y_E, y)[0]
Eq(y, y_HS)
# Out:
# y(t) = l₁⋅cos(θ₁(t)) + l₂⋅cos(θ₂(t)) + l₄⋅cos(φ_D - θ₃(t))

# %%
# Heel strike 2, dy/st
omega_3HS = solve(const_HS_u_E, omega_3)[0]
Eq(omega_3, omega_3HS)
# Out:
#              ⎛              d                         d            ⎞
#             -⎜l₁⋅cos(θ₁(t))⋅──(θ₁(t)) + l₂⋅cos(θ₂(t))⋅──(θ₂(t)) + v⎟
# d            ⎝              dt                        dt           ⎠
# ──(θ₃(t)) = ─────────────────────────────────────────────────────────
# dt                             l₄⋅cos(φ_D - θ₃(t))

# %%
# Foot Planted 1: y
y_FP = solve(const_FP_y_E, y)[0]
Eq(y, y_FP)
# Out:
# y(t) = l₁⋅cos(θ₁(t)) + l₂⋅cos(θ₂(t)) + l₄⋅cos(φ_D - θ₃(t))

# %%
# Foot planted 2: theta_3
theta_3FP = simplify(solve(const_FP_y_D.subs(y, y_FP), theta_3)[0])
# theta_1FP = theta_1FP.
Eq(theta_3, theta_3FP)
# Out:
#                ⎛⎛                    _________________________________________ ↪
#                ⎜⎜        ⎛φ_D⎞      ╱   2    4⎛φ_D⎞       2    2⎛φ_D⎞     2    ↪
#                ⎜⎜2⋅l₄⋅tan⎜───⎟ -   ╱  l₃ ⋅tan ⎜───⎟ + 2⋅l₃ ⋅tan ⎜───⎟ + l₃  +  ↪
#                ⎜⎝        ⎝ 2 ⎠   ╲╱           ⎝ 2 ⎠             ⎝ 2 ⎠          ↪
# θ₃(t) = -2⋅atan⎜────────────────────────────────────────────────────────────── ↪
#                ⎜                                                               ↪
#                ⎜                                                          l₃ - ↪
#                ⎝                                                               ↪
#
# ↪ ____________________________________________________________________⎞        ↪
# ↪            4⎛φ_D⎞               2    4⎛φ_D⎞       2    2⎛φ_D⎞     2 ⎟    2⎛φ ↪
# ↪ 2⋅l₃⋅l₄⋅tan ⎜───⎟ - 2⋅l₃⋅l₄ + l₄ ⋅tan ⎜───⎟ + 2⋅l₄ ⋅tan ⎜───⎟ + l₄  ⎟⋅cos ⎜─ ↪
# ↪             ⎝ 2 ⎠                     ⎝ 2 ⎠             ⎝ 2 ⎠       ⎠     ⎝  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪          2⎛φ_D⎞                                                              ↪
# ↪  2⋅l₄⋅cos ⎜───⎟ + l₄                                                         ↪
# ↪           ⎝ 2 ⎠                                                              ↪
#
# ↪    ⎞
# ↪ _D⎞⎟
# ↪ ──⎟⎟
# ↪ 2 ⎠⎟
# ↪ ───⎟
# ↪    ⎟
# ↪    ⎟
# ↪    ⎠

# %%
# Foot planted 3: omega_2
omega_2FP = solve(const_FP_u_E.subs(y, y_FP).subs(theta_3, theta_3FP), omega_2)[0]
Eq(omega_2, omega_2FP)
# Out:
#                             d
#             - l₁⋅cos(θ₁(t))⋅──(θ₁(t)) - v
# d                           dt
# ──(θ₂(t)) = ─────────────────────────────
# dt                  l₂⋅cos(θ₂(t))

# %%
# Toe lift-off 1: y
y_TLO = solve(const_TLO_y_D, y)[0]
Eq(y, y_TLO)
# Out:
# y(t) = l₁⋅cos(θ₁(t)) + l₂⋅cos(θ₂(t)) + l₃⋅cos(θ₃(t))

# %%
# Toe lift-off 2: omega_3
omega_3TLO = solve(const_TLO_u_D.subs(y, y_TLO), omega_3)[0]
Eq(omega_3, omega_3TLO)
# Out:
#              ⎛              d                         d            ⎞
#             -⎜l₁⋅cos(θ₁(t))⋅──(θ₁(t)) + l₂⋅cos(θ₂(t))⋅──(θ₂(t)) + v⎟
# d            ⎝              dt                        dt           ⎠
# ──(θ₃(t)) = ─────────────────────────────────────────────────────────
# dt                                l₃⋅cos(θ₃(t))

# %% [markdown]
# Virtual Work

# %%
dw_A = -g * m_A * diff(y_A, t)

# %%
dw_1 = -g * m_1 * diff(y_1, t)

# %%
dw_2 = -g * m_2 * diff(y_2, t)

# %%
dw_3 = -g * m_3 * diff(y_3, t)

# %%
dw = simplify(dw_A + dw_1 + dw_2 + dw_3)

# %%
dw.collect(diff(theta_3, t))
# Out:
#    ⎛                 d                              d                          ↪
# -g⋅⎜l₁⋅m₁⋅sin(θ₁(t))⋅──(θ₁(t)) + 2⋅l₁⋅m₂⋅sin(θ₁(t))⋅──(θ₁(t)) + 2⋅l₁⋅m₃⋅sin(θ₁ ↪
#    ⎝                 dt                             dt                         ↪
# ────────────────────────────────────────────────────────────────────────────── ↪
#                                                                                ↪
#
# ↪      d                            d                              d           ↪
# ↪ (t))⋅──(θ₁(t)) + l₂⋅m₂⋅sin(θ₂(t))⋅──(θ₂(t)) + 2⋅l₂⋅m₃⋅sin(θ₂(t))⋅──(θ₂(t)) + ↪
# ↪      dt                           dt                             dt          ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                              2                               ↪
#
# ↪                   d                d               d               d         ↪
# ↪  l₃⋅m₃⋅sin(θ₃(t))⋅──(θ₃(t)) + 2⋅m₁⋅──(y(t)) + 2⋅m₂⋅──(y(t)) + 2⋅m₃⋅──(y(t))  ↪
# ↪                   dt               dt              dt              dt        ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
#
# ↪         d       ⎞
# ↪ + 2⋅m_A⋅──(y(t))⎟
# ↪         dt      ⎠
# ↪ ──────────────────
# ↪

# %%
print(dw.collect(diff(theta_3, t)))
# Out:
# -g*(l_1*m_1*sin(theta_1(t))*Derivative(theta_1(t), t) + 2*l_1*m_2*sin(theta_1(t))*Derivative(theta_1(t), t) + 2*l_1*m_3*sin(theta_1(t))*Derivative(theta_1(t), t) + l_2*m_2*sin(theta_2(t))*Derivative(theta_2(t), t) + 2*l_2*m_3*sin(theta_2(t))*Derivative(theta_2(t), t) + l_3*m_3*sin(theta_3(t))*Derivative(theta_3(t), t) + 2*m_1*Derivative(y(t), t) + 2*m_2*Derivative(y(t), t) + 2*m_3*Derivative(y(t), t) + 2*m_A*Derivative(y(t), t))/2

# %%
dw.collect(diff(theta_2, t))
# Out:
#    ⎛                 d                              d                          ↪
# -g⋅⎜l₁⋅m₁⋅sin(θ₁(t))⋅──(θ₁(t)) + 2⋅l₁⋅m₂⋅sin(θ₁(t))⋅──(θ₁(t)) + 2⋅l₁⋅m₃⋅sin(θ₁ ↪
#    ⎝                 dt                             dt                         ↪
# ────────────────────────────────────────────────────────────────────────────── ↪
#                                                                                ↪
#
# ↪      d                            d                d               d         ↪
# ↪ (t))⋅──(θ₁(t)) + l₃⋅m₃⋅sin(θ₃(t))⋅──(θ₃(t)) + 2⋅m₁⋅──(y(t)) + 2⋅m₂⋅──(y(t))  ↪
# ↪      dt                           dt               dt              dt        ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                          2                                   ↪
#
# ↪        d                d                                                  d ↪
# ↪ + 2⋅m₃⋅──(y(t)) + 2⋅m_A⋅──(y(t)) + (l₂⋅m₂⋅sin(θ₂(t)) + 2⋅l₂⋅m₃⋅sin(θ₂(t)))⋅─ ↪
# ↪        dt               dt                                                 d ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
#
# ↪         ⎞
# ↪ ─(θ₂(t))⎟
# ↪ t       ⎠
# ↪ ──────────
# ↪

# %%
print(dw.collect(diff(theta_2, t)))
# Out:
# -g*(l_1*m_1*sin(theta_1(t))*Derivative(theta_1(t), t) + 2*l_1*m_2*sin(theta_1(t))*Derivative(theta_1(t), t) + 2*l_1*m_3*sin(theta_1(t))*Derivative(theta_1(t), t) + l_3*m_3*sin(theta_3(t))*Derivative(theta_3(t), t) + 2*m_1*Derivative(y(t), t) + 2*m_2*Derivative(y(t), t) + 2*m_3*Derivative(y(t), t) + 2*m_A*Derivative(y(t), t) + (l_2*m_2*sin(theta_2(t)) + 2*l_2*m_3*sin(theta_2(t)))*Derivative(theta_2(t), t))/2

# %%
dw.collect(diff(theta_1, t))
# Out:
#    ⎛                 d                              d                          ↪
# -g⋅⎜l₂⋅m₂⋅sin(θ₂(t))⋅──(θ₂(t)) + 2⋅l₂⋅m₃⋅sin(θ₂(t))⋅──(θ₂(t)) + l₃⋅m₃⋅sin(θ₃(t ↪
#    ⎝                 dt                             dt                         ↪
# ────────────────────────────────────────────────────────────────────────────── ↪
#                                                                                ↪
#
# ↪    d                d               d               d                d       ↪
# ↪ ))⋅──(θ₃(t)) + 2⋅m₁⋅──(y(t)) + 2⋅m₂⋅──(y(t)) + 2⋅m₃⋅──(y(t)) + 2⋅m_A⋅──(y(t) ↪
# ↪    dt               dt              dt              dt               dt      ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                     2                                        ↪
#
# ↪                                                                  d        ⎞
# ↪ ) + (l₁⋅m₁⋅sin(θ₁(t)) + 2⋅l₁⋅m₂⋅sin(θ₁(t)) + 2⋅l₁⋅m₃⋅sin(θ₁(t)))⋅──(θ₁(t))⎟
# ↪                                                                  dt       ⎠
# ↪ ────────────────────────────────────────────────────────────────────────────
# ↪

# %%
print(dw.collect(diff(theta_1, t)))
# Out:
# -g*(l_2*m_2*sin(theta_2(t))*Derivative(theta_2(t), t) + 2*l_2*m_3*sin(theta_2(t))*Derivative(theta_2(t), t) + l_3*m_3*sin(theta_3(t))*Derivative(theta_3(t), t) + 2*m_1*Derivative(y(t), t) + 2*m_2*Derivative(y(t), t) + 2*m_3*Derivative(y(t), t) + 2*m_A*Derivative(y(t), t) + (l_1*m_1*sin(theta_1(t)) + 2*l_1*m_2*sin(theta_1(t)) + 2*l_1*m_3*sin(theta_1(t)))*Derivative(theta_1(t), t))/2

# %%
dw.collect(diff(y, t))
# Out:
#    ⎛                 d                              d                          ↪
# -g⋅⎜l₁⋅m₁⋅sin(θ₁(t))⋅──(θ₁(t)) + 2⋅l₁⋅m₂⋅sin(θ₁(t))⋅──(θ₁(t)) + 2⋅l₁⋅m₃⋅sin(θ₁ ↪
#    ⎝                 dt                             dt                         ↪
# ────────────────────────────────────────────────────────────────────────────── ↪
#                                                                                ↪
#
# ↪      d                            d                              d           ↪
# ↪ (t))⋅──(θ₁(t)) + l₂⋅m₂⋅sin(θ₂(t))⋅──(θ₂(t)) + 2⋅l₂⋅m₃⋅sin(θ₂(t))⋅──(θ₂(t)) + ↪
# ↪      dt                           dt                             dt          ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                  2                                           ↪
#
# ↪                   d                                        d       ⎞
# ↪  l₃⋅m₃⋅sin(θ₃(t))⋅──(θ₃(t)) + (2⋅m₁ + 2⋅m₂ + 2⋅m₃ + 2⋅m_A)⋅──(y(t))⎟
# ↪                   dt                                       dt      ⎠
# ↪ ─────────────────────────────────────────────────────────────────────
# ↪

# %%
print(dw.collect(diff(y, t)))
# Out:
# -g*(l_1*m_1*sin(theta_1(t))*Derivative(theta_1(t), t) + 2*l_1*m_2*sin(theta_1(t))*Derivative(theta_1(t), t) + 2*l_1*m_3*sin(theta_1(t))*Derivative(theta_1(t), t) + l_2*m_2*sin(theta_2(t))*Derivative(theta_2(t), t) + 2*l_2*m_3*sin(theta_2(t))*Derivative(theta_2(t), t) + l_3*m_3*sin(theta_3(t))*Derivative(theta_3(t), t) + (2*m_1 + 2*m_2 + 2*m_3 + 2*m_A)*Derivative(y(t), t))/2

# %% [markdown]
# Extract applied efforts

# %%
e_y = simplify(-g *(2*m_1 + 2*m_2 + 2*m_3 + 2*m_A)/2)
e_y
# Out:
# -g⋅(m₁ + m₂ + m₃ + m_A)

# %%
e_1 = simplify(-g * (l_1*m_1*sin(theta_1) + 2*l_1*m_2*sin(theta_1) + 2*l_1*m_3*sin(theta_1))/2)
e_1
# Out:
# -g⋅l₁⋅(m₁ + 2⋅m₂ + 2⋅m₃)⋅sin(θ₁(t))
# ────────────────────────────────────
#                  2

# %%
e_2 = simplify(-g * (l_2*m_2*sin(theta_2) + 2*l_2*m_3*sin(theta_2))/2)
e_2
# Out:
# -g⋅l₂⋅(m₂ + 2⋅m₃)⋅sin(θ₂(t))
# ─────────────────────────────
#               2

# %%
e_3 = simplify(- g * l_3*m_3*sin(theta_3) / 2)
e_3
# Out:
# -g⋅l₃⋅m₃⋅sin(θ₃(t))
# ────────────────────
#          2

# %% [markdown]
# Equations of Motion: General

# %%
# y
EOM_y = simplify(diff(diff(T, v_A), t) - diff(T, y) + diff(D, v_A) + diff(V, y) - e_y)
Eq(EOM_y, 0)
# Out:
#                             ⎛               2                                  ↪
#                             ⎜              d                          ⎛d       ↪
#                          m₁⋅⎜l₁⋅sin(θ₁(t))⋅───(θ₁(t)) + l₁⋅cos(θ₁(t))⋅⎜──(θ₁(t ↪
#                             ⎜                2                        ⎝dt      ↪
#                             ⎝              dt                                  ↪
# g⋅(m₁ + m₂ + m₃ + m_A) + ───────────────────────────────────────────────────── ↪
#                                                             2                  ↪
#
# ↪    2      2       ⎞      ⎛                 2                                 ↪
# ↪   ⎞      d        ⎟      ⎜                d                            ⎛d    ↪
# ↪ ))⎟  + 2⋅───(y(t))⎟   m₂⋅⎜2⋅l₁⋅sin(θ₁(t))⋅───(θ₁(t)) + 2⋅l₁⋅cos(θ₁(t))⋅⎜──(θ ↪
# ↪   ⎠        2      ⎟      ⎜                  2                          ⎝dt   ↪
# ↪          dt       ⎠      ⎝                dt                                 ↪
# ↪ ─────────────────── + ────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
#
# ↪       2                  2                                    2      2       ↪
# ↪      ⎞                  d                          ⎛d        ⎞      d        ↪
# ↪ ₁(t))⎟  + l₂⋅sin(θ₂(t))⋅───(θ₂(t)) + l₂⋅cos(θ₂(t))⋅⎜──(θ₂(t))⎟  + 2⋅───(y(t) ↪
# ↪      ⎠                    2                        ⎝dt       ⎠        2      ↪
# ↪                         dt                                          dt       ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪            2                                                                 ↪
#
# ↪  ⎞      ⎛                 2                                      2           ↪
# ↪  ⎟      ⎜                d                            ⎛d        ⎞            ↪
# ↪ )⎟   m₃⋅⎜2⋅l₁⋅sin(θ₁(t))⋅───(θ₁(t)) + 2⋅l₁⋅cos(θ₁(t))⋅⎜──(θ₁(t))⎟  + 2⋅l₂⋅si ↪
# ↪  ⎟      ⎜                  2                          ⎝dt       ⎠            ↪
# ↪  ⎠      ⎝                dt                                                  ↪
# ↪ ── + ─────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
#
# ↪           2                                      2                  2        ↪
# ↪          d                            ⎛d        ⎞                  d         ↪
# ↪ n(θ₂(t))⋅───(θ₂(t)) + 2⋅l₂⋅cos(θ₂(t))⋅⎜──(θ₂(t))⎟  + l₃⋅sin(θ₃(t))⋅───(θ₃(t) ↪
# ↪            2                          ⎝dt       ⎠                    2       ↪
# ↪          dt                                                        dt        ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                         2                                                    ↪
#
# ↪                              2      2       ⎞
# ↪                   ⎛d        ⎞      d        ⎟
# ↪ ) + l₃⋅cos(θ₃(t))⋅⎜──(θ₃(t))⎟  + 2⋅───(y(t))⎟
# ↪                   ⎝dt       ⎠        2      ⎟
# ↪                                    dt       ⎠
# ↪ ───────────────────────────────────────────── = 0
# ↪

# %%
# theta_1
EOM_1 = simplify(diff(diff(T, omega_1), t) - diff(T, theta_1) + diff(D, omega_1) + diff(V, theta_1) - e_1)
Eq(EOM_1, 0)
# Out:
#                                                                                ↪
#                                                                                ↪
#                                                                                ↪
#                                                                                ↪
#     d               d           g⋅l₁⋅m₁⋅sin(θ₁(t))                             ↪
# b_B⋅──(θ₁(t)) - b_B⋅──(θ₂(t)) + ────────────────── + g⋅l₁⋅m₂⋅sin(θ₁(t)) + g⋅l₁ ↪
#     dt              dt                  2                                      ↪
#                                                                                ↪
#
# ↪                                                            2                 ↪
# ↪                                                      2    d                  ↪
# ↪                                                    l₁ ⋅m₁⋅───(θ₁(t))         ↪
# ↪                                                             2                ↪
# ↪                                                           dt             2   ↪
# ↪ ⋅m₃⋅sin(θ₁(t)) - k_B⋅ψ_B + k_B⋅θ₁(t) - k_B⋅θ₂(t) + ───────────────── + l₁ ⋅m ↪
# ↪                                                            3                 ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                                           2  ↪
# ↪                                                                ⎛d        ⎞   ↪
# ↪    2                   2           l₁⋅l₂⋅m₂⋅sin(θ₁(t) - θ₂(t))⋅⎜──(θ₂(t))⎟   ↪
# ↪   d              2    d                                        ⎝dt       ⎠   ↪
# ↪ ₂⋅───(θ₁(t)) + l₁ ⋅m₃⋅───(θ₁(t)) + ────────────────────────────────────────  ↪
# ↪     2                   2                             2                      ↪
# ↪   dt                  dt                                                     ↪
#
# ↪                                2                                             ↪
# ↪                               d                                              ↪
# ↪   l₁⋅l₂⋅m₂⋅cos(θ₁(t) - θ₂(t))⋅───(θ₂(t))                                     ↪
# ↪                                 2                                            ↪
# ↪                               dt                                       ⎛d    ↪
# ↪ + ────────────────────────────────────── + l₁⋅l₂⋅m₃⋅sin(θ₁(t) - θ₂(t))⋅⎜──(θ ↪
# ↪                     2                                                  ⎝dt   ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪       2                                2           l₁⋅l₃⋅m₃⋅sin(θ₁(t) - θ₃(t ↪
# ↪      ⎞                                d                                      ↪
# ↪ ₂(t))⎟  + l₁⋅l₂⋅m₃⋅cos(θ₁(t) - θ₂(t))⋅───(θ₂(t)) + ───────────────────────── ↪
# ↪      ⎠                                  2                             2      ↪
# ↪                                       dt                                     ↪
#
# ↪                                                2                             ↪
# ↪               2                               d                              ↪
# ↪    ⎛d        ⎞    l₁⋅l₃⋅m₃⋅cos(θ₁(t) - θ₃(t))⋅───(θ₃(t))   l₁⋅m₁⋅sin(θ₁(t))⋅ ↪
# ↪ ))⋅⎜──(θ₃(t))⎟                                  2                            ↪
# ↪    ⎝dt       ⎠                                dt                             ↪
# ↪ ─────────────── + ────────────────────────────────────── + ───────────────── ↪
# ↪                                     2                                  2     ↪
# ↪                                                                              ↪
#
# ↪  2
# ↪ d
# ↪ ───(y(t))
# ↪   2                           2                            2
# ↪ dt                           d                            d
# ↪ ───────── + l₁⋅m₂⋅sin(θ₁(t))⋅───(y(t)) + l₁⋅m₃⋅sin(θ₁(t))⋅───(y(t)) = 0
# ↪                                2                            2
# ↪                              dt                           dt

# %%
# theta_2
EOM_2 = simplify(diff(diff(T, omega_2), t) - diff(T, theta_2) + diff(D, omega_2) + diff(V, theta_2)- e_2)
Eq(EOM_2, 0)
# Out:
#                                                                                ↪
#                                                                                ↪
#                                                                                ↪
#                                                                                ↪
#       d               d               d               d           g⋅l₂⋅m₂⋅sin( ↪
# - b_B⋅──(θ₁(t)) + b_B⋅──(θ₂(t)) + b_C⋅──(θ₂(t)) - b_C⋅──(θ₃(t)) + ──────────── ↪
#       dt              dt              dt              dt                  2    ↪
#                                                                                ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ θ₂(t))                                                                       ↪
# ↪ ────── + g⋅l₂⋅m₃⋅sin(θ₂(t)) + k_B⋅ψ_B - k_B⋅θ₁(t) + k_B⋅θ₂(t) - k_C⋅ψ_C + k_ ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                              2               ↪
# ↪                                                   ⎛d        ⎞    l₁⋅l₂⋅m₂⋅co ↪
# ↪                       l₁⋅l₂⋅m₂⋅sin(θ₁(t) - θ₂(t))⋅⎜──(θ₁(t))⎟                ↪
# ↪                                                   ⎝dt       ⎠                ↪
# ↪ C⋅θ₂(t) - k_C⋅θ₃(t) - ──────────────────────────────────────── + ─────────── ↪
# ↪                                          2                                   ↪
# ↪                                                                              ↪
#
# ↪                   2                                                          ↪
# ↪                  d                                                           ↪
# ↪ s(θ₁(t) - θ₂(t))⋅───(θ₁(t))                                                  ↪
# ↪                    2                                                 2       ↪
# ↪                  dt                                       ⎛d        ⎞        ↪
# ↪ ─────────────────────────── - l₁⋅l₂⋅m₃⋅sin(θ₁(t) - θ₂(t))⋅⎜──(θ₁(t))⎟  + l₁⋅ ↪
# ↪        2                                                  ⎝dt       ⎠        ↪
# ↪                                                                              ↪
#
# ↪                                               2                              ↪
# ↪                                         2    d                               ↪
# ↪                                       l₂ ⋅m₂⋅───(θ₂(t))                      ↪
# ↪                           2                    2                  2          ↪
# ↪                          d                   dt             2    d           ↪
# ↪ l₂⋅m₃⋅cos(θ₁(t) - θ₂(t))⋅───(θ₁(t)) + ───────────────── + l₂ ⋅m₃⋅───(θ₂(t))  ↪
# ↪                            2                  3                    2         ↪
# ↪                          dt                                      dt          ↪
#
# ↪                                                                           2  ↪
# ↪                                          2                               d   ↪
# ↪                               ⎛d        ⎞    l₂⋅l₃⋅m₃⋅cos(θ₂(t) - θ₃(t))⋅─── ↪
# ↪   l₂⋅l₃⋅m₃⋅sin(θ₂(t) - θ₃(t))⋅⎜──(θ₃(t))⎟                                  2 ↪
# ↪                               ⎝dt       ⎠                                dt  ↪
# ↪ + ──────────────────────────────────────── + ─────────────────────────────── ↪
# ↪                      2                                         2             ↪
# ↪                                                                              ↪
#
# ↪                             2
# ↪                            d
# ↪ (θ₃(t))   l₂⋅m₂⋅sin(θ₂(t))⋅───(y(t))
# ↪                              2                           2
# ↪                            dt                           d
# ↪ ─────── + ────────────────────────── + l₂⋅m₃⋅sin(θ₂(t))⋅───(y(t)) = 0
# ↪                       2                                   2
# ↪                                                         dt

# %%
# theta_3
EOM_3 = simplify(diff(diff(T, omega_3), t) - diff(T, theta_3) + diff(D, omega_3) + diff(V, theta_3) - e_3)
Eq(EOM_3, 0)
# Out:
#                                                                                ↪
#                                                                                ↪
#                                                                                ↪
#                                                                                ↪
#       d               d           g⋅l₃⋅m₃⋅sin(θ₃(t))                           ↪
# - b_C⋅──(θ₂(t)) + b_C⋅──(θ₃(t)) + ────────────────── + k_C⋅ψ_C - k_C⋅θ₂(t) + k ↪
#       dt              dt                  2                                    ↪
#
# ↪                                                                              ↪
# ↪                                                   2                          ↪
# ↪                                        ⎛d        ⎞    l₁⋅l₃⋅m₃⋅cos(θ₁(t) - θ ↪
# ↪            l₁⋅l₃⋅m₃⋅sin(θ₁(t) - θ₃(t))⋅⎜──(θ₁(t))⎟                           ↪
# ↪                                        ⎝dt       ⎠                           ↪
# ↪ _C⋅θ₃(t) - ──────────────────────────────────────── + ────────────────────── ↪
# ↪                               2                                         2    ↪
#
# ↪        2                                                                     ↪
# ↪       d                                                   2                  ↪
# ↪ ₃(t))⋅───(θ₁(t))                               ⎛d        ⎞    l₂⋅l₃⋅m₃⋅cos(θ ↪
# ↪         2          l₂⋅l₃⋅m₃⋅sin(θ₂(t) - θ₃(t))⋅⎜──(θ₂(t))⎟                   ↪
# ↪       dt                                       ⎝dt       ⎠                   ↪
# ↪ ──────────────── - ──────────────────────────────────────── + ────────────── ↪
# ↪                                       2                                      ↪
#
# ↪                2                   2                             2           ↪
# ↪               d              2    d                             d            ↪
# ↪ ₂(t) - θ₃(t))⋅───(θ₂(t))   l₃ ⋅m₃⋅───(θ₃(t))   l₃⋅m₃⋅sin(θ₃(t))⋅───(y(t))    ↪
# ↪                 2                   2                             2          ↪
# ↪               dt                  dt                            dt           ↪
# ↪ ──────────────────────── + ───────────────── + ────────────────────────── =  ↪
# ↪     2                              3                       2                 ↪
#
# ↪
# ↪
# ↪
# ↪
# ↪
# ↪ 0
# ↪

# %% [markdown]
# Swing Equations of Motion

# %%
EOM_SW_y = simplify(EOM_y.subs(y, y_A_SW))
Eq(EOM_SW_y, 0)
# Out:
#                             ⎛               2                                  ↪
#                             ⎜              d                          ⎛d       ↪
#                          m₁⋅⎜l₁⋅sin(θ₁(t))⋅───(θ₁(t)) + l₁⋅cos(θ₁(t))⋅⎜──(θ₁(t ↪
#                             ⎜                2                        ⎝dt      ↪
#                             ⎝              dt                                  ↪
# g⋅(m₁ + m₂ + m₃ + m_A) + ───────────────────────────────────────────────────── ↪
#                                                               2                ↪
#
# ↪    2      2           ⎞      ⎛                 2                             ↪
# ↪   ⎞      d            ⎟      ⎜                d                            ⎛ ↪
# ↪ ))⎟  + 2⋅───(y_ASW(t))⎟   m₂⋅⎜2⋅l₁⋅sin(θ₁(t))⋅───(θ₁(t)) + 2⋅l₁⋅cos(θ₁(t))⋅⎜ ↪
# ↪   ⎠        2          ⎟      ⎜                  2                          ⎝ ↪
# ↪          dt           ⎠      ⎝                dt                             ↪
# ↪ ─────────────────────── + ────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
#
# ↪           2                  2                                    2      2   ↪
# ↪ d        ⎞                  d                          ⎛d        ⎞      d    ↪
# ↪ ──(θ₁(t))⎟  + l₂⋅sin(θ₂(t))⋅───(θ₂(t)) + l₂⋅cos(θ₂(t))⋅⎜──(θ₂(t))⎟  + 2⋅───( ↪
# ↪ dt       ⎠                    2                        ⎝dt       ⎠        2  ↪
# ↪                             dt                                          dt   ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                  2                                                           ↪
#
# ↪          ⎞      ⎛                 2                                      2   ↪
# ↪          ⎟      ⎜                d                            ⎛d        ⎞    ↪
# ↪ y_ASW(t))⎟   m₃⋅⎜2⋅l₁⋅sin(θ₁(t))⋅───(θ₁(t)) + 2⋅l₁⋅cos(θ₁(t))⋅⎜──(θ₁(t))⎟  + ↪
# ↪          ⎟      ⎜                  2                          ⎝dt       ⎠    ↪
# ↪          ⎠      ⎝                dt                                          ↪
# ↪ ────────── + ─────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
#
# ↪                   2                                      2                   ↪
# ↪                  d                            ⎛d        ⎞                  d ↪
# ↪  2⋅l₂⋅sin(θ₂(t))⋅───(θ₂(t)) + 2⋅l₂⋅cos(θ₂(t))⋅⎜──(θ₂(t))⎟  + l₃⋅sin(θ₃(t))⋅─ ↪
# ↪                    2                          ⎝dt       ⎠                    ↪
# ↪                  dt                                                        d ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                   2                                          ↪
#
# ↪ 2                                    2      2           ⎞
# ↪                           ⎛d        ⎞      d            ⎟
# ↪ ──(θ₃(t)) + l₃⋅cos(θ₃(t))⋅⎜──(θ₃(t))⎟  + 2⋅───(y_ASW(t))⎟
# ↪  2                        ⎝dt       ⎠        2          ⎟
# ↪ t                                          dt           ⎠
# ↪ ───────────────────────────────────────────────────────── = 0
# ↪

# %%
EOM_SW_1 = simplify(EOM_1.subs(y, y_A_SW))
Eq(EOM_SW_1, 0)
# Out:
#                                                                                ↪
#                                                                                ↪
#                                                                                ↪
#                                                                                ↪
#     d               d           g⋅l₁⋅m₁⋅sin(θ₁(t))                             ↪
# b_B⋅──(θ₁(t)) - b_B⋅──(θ₂(t)) + ────────────────── + g⋅l₁⋅m₂⋅sin(θ₁(t)) + g⋅l₁ ↪
#     dt              dt                  2                                      ↪
#                                                                                ↪
#
# ↪                                                            2                 ↪
# ↪                                                      2    d                  ↪
# ↪                                                    l₁ ⋅m₁⋅───(θ₁(t))         ↪
# ↪                                                             2                ↪
# ↪                                                           dt             2   ↪
# ↪ ⋅m₃⋅sin(θ₁(t)) - k_B⋅ψ_B + k_B⋅θ₁(t) - k_B⋅θ₂(t) + ───────────────── + l₁ ⋅m ↪
# ↪                                                            3                 ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                                           2  ↪
# ↪                                                                ⎛d        ⎞   ↪
# ↪    2                   2           l₁⋅l₂⋅m₂⋅sin(θ₁(t) - θ₂(t))⋅⎜──(θ₂(t))⎟   ↪
# ↪   d              2    d                                        ⎝dt       ⎠   ↪
# ↪ ₂⋅───(θ₁(t)) + l₁ ⋅m₃⋅───(θ₁(t)) + ────────────────────────────────────────  ↪
# ↪     2                   2                             2                      ↪
# ↪   dt                  dt                                                     ↪
#
# ↪                                2                                             ↪
# ↪                               d                                              ↪
# ↪   l₁⋅l₂⋅m₂⋅cos(θ₁(t) - θ₂(t))⋅───(θ₂(t))                                     ↪
# ↪                                 2                                            ↪
# ↪                               dt                                       ⎛d    ↪
# ↪ + ────────────────────────────────────── + l₁⋅l₂⋅m₃⋅sin(θ₁(t) - θ₂(t))⋅⎜──(θ ↪
# ↪                     2                                                  ⎝dt   ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪       2                                2           l₁⋅l₃⋅m₃⋅sin(θ₁(t) - θ₃(t ↪
# ↪      ⎞                                d                                      ↪
# ↪ ₂(t))⎟  + l₁⋅l₂⋅m₃⋅cos(θ₁(t) - θ₂(t))⋅───(θ₂(t)) + ───────────────────────── ↪
# ↪      ⎠                                  2                             2      ↪
# ↪                                       dt                                     ↪
#
# ↪                                                2                             ↪
# ↪               2                               d                              ↪
# ↪    ⎛d        ⎞    l₁⋅l₃⋅m₃⋅cos(θ₁(t) - θ₃(t))⋅───(θ₃(t))   l₁⋅m₁⋅sin(θ₁(t))⋅ ↪
# ↪ ))⋅⎜──(θ₃(t))⎟                                  2                            ↪
# ↪    ⎝dt       ⎠                                dt                             ↪
# ↪ ─────────────── + ────────────────────────────────────── + ───────────────── ↪
# ↪                                     2                                    2   ↪
# ↪                                                                              ↪
#
# ↪  2                                                                           ↪
# ↪ d                                                                            ↪
# ↪ ───(y_ASW(t))                                                                ↪
# ↪   2                               2                                2         ↪
# ↪ dt                               d                                d          ↪
# ↪ ───────────── + l₁⋅m₂⋅sin(θ₁(t))⋅───(y_ASW(t)) + l₁⋅m₃⋅sin(θ₁(t))⋅───(y_ASW( ↪
# ↪                                    2                                2        ↪
# ↪                                  dt                               dt         ↪
#
# ↪
# ↪
# ↪
# ↪
# ↪
# ↪ t)) = 0
# ↪
# ↪

# %%
Eq(diff(diff(theta_1, t), t), simplify(solve(EOM_SW_1, diff(diff(theta_1, t), t))[0]))
# Out:
#                ⎛                                                               ↪
#                ⎜        d                 d                                    ↪
#              3⋅⎜- 2⋅b_B⋅──(θ₁(t)) + 2⋅b_B⋅──(θ₂(t)) - g⋅l₁⋅m₁⋅sin(θ₁(t)) - 2⋅g ↪
#  2             ⎜        dt                dt                                   ↪
# d              ⎝                                                               ↪
# ───(θ₁(t)) = ───────────────────────────────────────────────────────────────── ↪
#   2                                                                            ↪
# dt                                                                             ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ ⋅l₁⋅m₂⋅sin(θ₁(t)) - 2⋅g⋅l₁⋅m₃⋅sin(θ₁(t)) + 2⋅k_B⋅ψ_B - 2⋅k_B⋅θ₁(t) + 2⋅k_B⋅θ ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                               2                              ↪
# ↪                                    ⎛d        ⎞                               ↪
# ↪ ₂(t) - l₁⋅l₂⋅m₂⋅sin(θ₁(t) - θ₂(t))⋅⎜──(θ₂(t))⎟  - l₁⋅l₂⋅m₂⋅cos(θ₁(t) - θ₂(t) ↪
# ↪                                    ⎝dt       ⎠                               ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪    2                                                    2                    ↪
# ↪   d                                          ⎛d        ⎞                     ↪
# ↪ )⋅───(θ₂(t)) - 2⋅l₁⋅l₂⋅m₃⋅sin(θ₁(t) - θ₂(t))⋅⎜──(θ₂(t))⎟  - 2⋅l₁⋅l₂⋅m₃⋅cos(θ ↪
# ↪     2                                        ⎝dt       ⎠                     ↪
# ↪   dt                                                                         ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                            2                                                 ↪
# ↪                        2⋅l₁ ⋅(m₁ + 3⋅m₂ + 3⋅m₃)                              ↪
#
# ↪                2                                                  2          ↪
# ↪               d                                        ⎛d        ⎞           ↪
# ↪ ₁(t) - θ₂(t))⋅───(θ₂(t)) - l₁⋅l₃⋅m₃⋅sin(θ₁(t) - θ₃(t))⋅⎜──(θ₃(t))⎟  - l₁⋅l₃⋅ ↪
# ↪                 2                                      ⎝dt       ⎠           ↪
# ↪               dt                                                             ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                        2                             2                       ↪
# ↪                       d                             d                        ↪
# ↪ m₃⋅cos(θ₁(t) - θ₃(t))⋅───(θ₃(t)) - l₁⋅m₁⋅sin(θ₁(t))⋅───(y_ASW(t)) - 2⋅l₁⋅m₂⋅ ↪
# ↪                         2                             2                      ↪
# ↪                       dt                            dt                       ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪             2                                  2           ⎞
# ↪            d                                  d            ⎟
# ↪ sin(θ₁(t))⋅───(y_ASW(t)) - 2⋅l₁⋅m₃⋅sin(θ₁(t))⋅───(y_ASW(t))⎟
# ↪              2                                  2          ⎟
# ↪            dt                                 dt           ⎠
# ↪ ────────────────────────────────────────────────────────────
# ↪
# ↪

# %%
EOM_SW_2 = simplify(EOM_y.subs(y, y_A_SW))
Eq(EOM_SW_2, 0)
# Out:
#                             ⎛               2                                  ↪
#                             ⎜              d                          ⎛d       ↪
#                          m₁⋅⎜l₁⋅sin(θ₁(t))⋅───(θ₁(t)) + l₁⋅cos(θ₁(t))⋅⎜──(θ₁(t ↪
#                             ⎜                2                        ⎝dt      ↪
#                             ⎝              dt                                  ↪
# g⋅(m₁ + m₂ + m₃ + m_A) + ───────────────────────────────────────────────────── ↪
#                                                               2                ↪
#
# ↪    2      2           ⎞      ⎛                 2                             ↪
# ↪   ⎞      d            ⎟      ⎜                d                            ⎛ ↪
# ↪ ))⎟  + 2⋅───(y_ASW(t))⎟   m₂⋅⎜2⋅l₁⋅sin(θ₁(t))⋅───(θ₁(t)) + 2⋅l₁⋅cos(θ₁(t))⋅⎜ ↪
# ↪   ⎠        2          ⎟      ⎜                  2                          ⎝ ↪
# ↪          dt           ⎠      ⎝                dt                             ↪
# ↪ ─────────────────────── + ────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
#
# ↪           2                  2                                    2      2   ↪
# ↪ d        ⎞                  d                          ⎛d        ⎞      d    ↪
# ↪ ──(θ₁(t))⎟  + l₂⋅sin(θ₂(t))⋅───(θ₂(t)) + l₂⋅cos(θ₂(t))⋅⎜──(θ₂(t))⎟  + 2⋅───( ↪
# ↪ dt       ⎠                    2                        ⎝dt       ⎠        2  ↪
# ↪                             dt                                          dt   ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                  2                                                           ↪
#
# ↪          ⎞      ⎛                 2                                      2   ↪
# ↪          ⎟      ⎜                d                            ⎛d        ⎞    ↪
# ↪ y_ASW(t))⎟   m₃⋅⎜2⋅l₁⋅sin(θ₁(t))⋅───(θ₁(t)) + 2⋅l₁⋅cos(θ₁(t))⋅⎜──(θ₁(t))⎟  + ↪
# ↪          ⎟      ⎜                  2                          ⎝dt       ⎠    ↪
# ↪          ⎠      ⎝                dt                                          ↪
# ↪ ────────── + ─────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
#
# ↪                   2                                      2                   ↪
# ↪                  d                            ⎛d        ⎞                  d ↪
# ↪  2⋅l₂⋅sin(θ₂(t))⋅───(θ₂(t)) + 2⋅l₂⋅cos(θ₂(t))⋅⎜──(θ₂(t))⎟  + l₃⋅sin(θ₃(t))⋅─ ↪
# ↪                    2                          ⎝dt       ⎠                    ↪
# ↪                  dt                                                        d ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                   2                                          ↪
#
# ↪ 2                                    2      2           ⎞
# ↪                           ⎛d        ⎞      d            ⎟
# ↪ ──(θ₃(t)) + l₃⋅cos(θ₃(t))⋅⎜──(θ₃(t))⎟  + 2⋅───(y_ASW(t))⎟
# ↪  2                        ⎝dt       ⎠        2          ⎟
# ↪ t                                          dt           ⎠
# ↪ ───────────────────────────────────────────────────────── = 0
# ↪

# %%
Eq(diff(diff(theta_2, t), t), simplify(solve(EOM_SW_2, diff(diff(theta_2, t), t))[0]))
# Out:
#               ⎛                                                       2        ↪
#               ⎜                                                      d         ↪
#              -⎜2⋅g⋅m₁ + 2⋅g⋅m₂ + 2⋅g⋅m₃ + 2⋅g⋅m_A + l₁⋅m₁⋅sin(θ₁(t))⋅───(θ₁(t) ↪
#  2            ⎜                                                        2       ↪
# d             ⎝                                                      dt        ↪
# ───(θ₂(t)) = ───────────────────────────────────────────────────────────────── ↪
#   2                                                                            ↪
# dt                                                                             ↪
#
# ↪                                 2                       2                    ↪
# ↪                      ⎛d        ⎞                       d                     ↪
# ↪ ) + l₁⋅m₁⋅cos(θ₁(t))⋅⎜──(θ₁(t))⎟  + 2⋅l₁⋅m₂⋅sin(θ₁(t))⋅───(θ₁(t)) + 2⋅l₁⋅m₂⋅ ↪
# ↪                      ⎝dt       ⎠                         2                   ↪
# ↪                                                        dt                    ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                       2                       2                              ↪
# ↪            ⎛d        ⎞                       d                               ↪
# ↪ cos(θ₁(t))⋅⎜──(θ₁(t))⎟  + 2⋅l₁⋅m₃⋅sin(θ₁(t))⋅───(θ₁(t)) + 2⋅l₁⋅m₃⋅cos(θ₁(t)) ↪
# ↪            ⎝dt       ⎠                         2                             ↪
# ↪                                              dt                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                           l₂⋅(m₂ + 2⋅m₃)⋅sin ↪
# ↪                                                                              ↪
#
# ↪             2                               2                                ↪
# ↪  ⎛d        ⎞                     ⎛d        ⎞                       ⎛d        ↪
# ↪ ⋅⎜──(θ₁(t))⎟  + l₂⋅m₂⋅cos(θ₂(t))⋅⎜──(θ₂(t))⎟  + 2⋅l₂⋅m₃⋅cos(θ₂(t))⋅⎜──(θ₂(t) ↪
# ↪  ⎝dt       ⎠                     ⎝dt       ⎠                       ⎝dt       ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪ (θ₂(t))                                                                      ↪
# ↪                                                                              ↪
#
# ↪   2                     2                                       2         2  ↪
# ↪  ⎞                     d                             ⎛d        ⎞         d   ↪
# ↪ )⎟  + l₃⋅m₃⋅sin(θ₃(t))⋅───(θ₃(t)) + l₃⋅m₃⋅cos(θ₃(t))⋅⎜──(θ₃(t))⎟  + 2⋅m₁⋅─── ↪
# ↪  ⎠                       2                           ⎝dt       ⎠           2 ↪
# ↪                        dt                                                dt  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                    2                    2           ⎞
# ↪                   d                    d            ⎟
# ↪ (y_ASW(t)) + 2⋅m₂⋅───(y_ASW(t)) + 2⋅m₃⋅───(y_ASW(t))⎟
# ↪                     2                    2          ⎟
# ↪                   dt                   dt           ⎠
# ↪ ──────────────────────────────────────────────────────
# ↪
# ↪

# %%
EOM_SW_3 = simplify(EOM_y.subs(y, y_A_SW))
Eq(EOM_SW_3, 0)
# Out:
#                             ⎛               2                                  ↪
#                             ⎜              d                          ⎛d       ↪
#                          m₁⋅⎜l₁⋅sin(θ₁(t))⋅───(θ₁(t)) + l₁⋅cos(θ₁(t))⋅⎜──(θ₁(t ↪
#                             ⎜                2                        ⎝dt      ↪
#                             ⎝              dt                                  ↪
# g⋅(m₁ + m₂ + m₃ + m_A) + ───────────────────────────────────────────────────── ↪
#                                                               2                ↪
#
# ↪    2      2           ⎞      ⎛                 2                             ↪
# ↪   ⎞      d            ⎟      ⎜                d                            ⎛ ↪
# ↪ ))⎟  + 2⋅───(y_ASW(t))⎟   m₂⋅⎜2⋅l₁⋅sin(θ₁(t))⋅───(θ₁(t)) + 2⋅l₁⋅cos(θ₁(t))⋅⎜ ↪
# ↪   ⎠        2          ⎟      ⎜                  2                          ⎝ ↪
# ↪          dt           ⎠      ⎝                dt                             ↪
# ↪ ─────────────────────── + ────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
#
# ↪           2                  2                                    2      2   ↪
# ↪ d        ⎞                  d                          ⎛d        ⎞      d    ↪
# ↪ ──(θ₁(t))⎟  + l₂⋅sin(θ₂(t))⋅───(θ₂(t)) + l₂⋅cos(θ₂(t))⋅⎜──(θ₂(t))⎟  + 2⋅───( ↪
# ↪ dt       ⎠                    2                        ⎝dt       ⎠        2  ↪
# ↪                             dt                                          dt   ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                  2                                                           ↪
#
# ↪          ⎞      ⎛                 2                                      2   ↪
# ↪          ⎟      ⎜                d                            ⎛d        ⎞    ↪
# ↪ y_ASW(t))⎟   m₃⋅⎜2⋅l₁⋅sin(θ₁(t))⋅───(θ₁(t)) + 2⋅l₁⋅cos(θ₁(t))⋅⎜──(θ₁(t))⎟  + ↪
# ↪          ⎟      ⎜                  2                          ⎝dt       ⎠    ↪
# ↪          ⎠      ⎝                dt                                          ↪
# ↪ ────────── + ─────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
#
# ↪                   2                                      2                   ↪
# ↪                  d                            ⎛d        ⎞                  d ↪
# ↪  2⋅l₂⋅sin(θ₂(t))⋅───(θ₂(t)) + 2⋅l₂⋅cos(θ₂(t))⋅⎜──(θ₂(t))⎟  + l₃⋅sin(θ₃(t))⋅─ ↪
# ↪                    2                          ⎝dt       ⎠                    ↪
# ↪                  dt                                                        d ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                   2                                          ↪
#
# ↪ 2                                    2      2           ⎞
# ↪                           ⎛d        ⎞      d            ⎟
# ↪ ──(θ₃(t)) + l₃⋅cos(θ₃(t))⋅⎜──(θ₃(t))⎟  + 2⋅───(y_ASW(t))⎟
# ↪  2                        ⎝dt       ⎠        2          ⎟
# ↪ t                                          dt           ⎠
# ↪ ───────────────────────────────────────────────────────── = 0
# ↪

# %%
Eq(diff(diff(theta_3, t), t), simplify(solve(EOM_SW_3, diff(diff(theta_3, t), t))[0]))
# Out:
#               ⎛                                                       2        ↪
#               ⎜                                                      d         ↪
#              -⎜2⋅g⋅m₁ + 2⋅g⋅m₂ + 2⋅g⋅m₃ + 2⋅g⋅m_A + l₁⋅m₁⋅sin(θ₁(t))⋅───(θ₁(t) ↪
#  2            ⎜                                                        2       ↪
# d             ⎝                                                      dt        ↪
# ───(θ₃(t)) = ───────────────────────────────────────────────────────────────── ↪
#   2                                                                            ↪
# dt                                                                             ↪
#
# ↪                                 2                       2                    ↪
# ↪                      ⎛d        ⎞                       d                     ↪
# ↪ ) + l₁⋅m₁⋅cos(θ₁(t))⋅⎜──(θ₁(t))⎟  + 2⋅l₁⋅m₂⋅sin(θ₁(t))⋅───(θ₁(t)) + 2⋅l₁⋅m₂⋅ ↪
# ↪                      ⎝dt       ⎠                         2                   ↪
# ↪                                                        dt                    ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                       2                       2                              ↪
# ↪            ⎛d        ⎞                       d                               ↪
# ↪ cos(θ₁(t))⋅⎜──(θ₁(t))⎟  + 2⋅l₁⋅m₃⋅sin(θ₁(t))⋅───(θ₁(t)) + 2⋅l₁⋅m₃⋅cos(θ₁(t)) ↪
# ↪            ⎝dt       ⎠                         2                             ↪
# ↪                                              dt                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪             2                     2                                       2  ↪
# ↪  ⎛d        ⎞                     d                             ⎛d        ⎞   ↪
# ↪ ⋅⎜──(θ₁(t))⎟  + l₂⋅m₂⋅sin(θ₂(t))⋅───(θ₂(t)) + l₂⋅m₂⋅cos(θ₂(t))⋅⎜──(θ₂(t))⎟   ↪
# ↪  ⎝dt       ⎠                       2                           ⎝dt       ⎠   ↪
# ↪                                  dt                                          ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪   l₃⋅m₃⋅sin(θ₃(t))                                                           ↪
# ↪                                                                              ↪
#
# ↪                       2                                         2            ↪
# ↪                      d                               ⎛d        ⎞             ↪
# ↪ + 2⋅l₂⋅m₃⋅sin(θ₂(t))⋅───(θ₂(t)) + 2⋅l₂⋅m₃⋅cos(θ₂(t))⋅⎜──(θ₂(t))⎟  + l₃⋅m₃⋅co ↪
# ↪                        2                             ⎝dt       ⎠             ↪
# ↪                      dt                                                      ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                     2         2                    2                    2    ↪
# ↪          ⎛d        ⎞         d                    d                    d     ↪
# ↪ s(θ₃(t))⋅⎜──(θ₃(t))⎟  + 2⋅m₁⋅───(y_ASW(t)) + 2⋅m₂⋅───(y_ASW(t)) + 2⋅m₃⋅───(y ↪
# ↪          ⎝dt       ⎠           2                    2                    2   ↪
# ↪                              dt                   dt                   dt    ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪         ⎞
# ↪         ⎟
# ↪ _ASW(t))⎟
# ↪         ⎟
# ↪         ⎠
# ↪ ──────────
# ↪
# ↪

# %% [markdown]
# Heel Strike Equations of Motion

# %%
EOM_HS_1 = simplify(EOM_1.subs(y, y_HS) + mu_1 * l_1 * cos(theta_1))
Eq(EOM_HS_1, 0)
# Out:
#                                                                                ↪
#                                                                                ↪
#                                                                                ↪
#                                                                                ↪
#     d               d           g⋅l₁⋅m₁⋅sin(θ₁(t))                             ↪
# b_B⋅──(θ₁(t)) - b_B⋅──(θ₂(t)) + ────────────────── + g⋅l₁⋅m₂⋅sin(θ₁(t)) + g⋅l₁ ↪
#     dt              dt                  2                                      ↪
#                                                                                ↪
#
# ↪                                                            2                 ↪
# ↪                                                      2    d                  ↪
# ↪                                                    l₁ ⋅m₁⋅───(θ₁(t))         ↪
# ↪                                                             2                ↪
# ↪                                                           dt             2   ↪
# ↪ ⋅m₃⋅sin(θ₁(t)) - k_B⋅ψ_B + k_B⋅θ₁(t) - k_B⋅θ₂(t) + ───────────────── + l₁ ⋅m ↪
# ↪                                                            3                 ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                                           2  ↪
# ↪                                                                ⎛d        ⎞   ↪
# ↪    2                   2           l₁⋅l₂⋅m₂⋅sin(θ₁(t) - θ₂(t))⋅⎜──(θ₂(t))⎟   ↪
# ↪   d              2    d                                        ⎝dt       ⎠   ↪
# ↪ ₂⋅───(θ₁(t)) + l₁ ⋅m₃⋅───(θ₁(t)) + ────────────────────────────────────────  ↪
# ↪     2                   2                             2                      ↪
# ↪   dt                  dt                                                     ↪
#
# ↪                                2                                             ↪
# ↪                               d                                              ↪
# ↪   l₁⋅l₂⋅m₂⋅cos(θ₁(t) - θ₂(t))⋅───(θ₂(t))                                     ↪
# ↪                                 2                                            ↪
# ↪                               dt                                       ⎛d    ↪
# ↪ + ────────────────────────────────────── + l₁⋅l₂⋅m₃⋅sin(θ₁(t) - θ₂(t))⋅⎜──(θ ↪
# ↪                     2                                                  ⎝dt   ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪       2                                2           l₁⋅l₃⋅m₃⋅sin(θ₁(t) - θ₃(t ↪
# ↪      ⎞                                d                                      ↪
# ↪ ₂(t))⎟  + l₁⋅l₂⋅m₃⋅cos(θ₁(t) - θ₂(t))⋅───(θ₂(t)) + ───────────────────────── ↪
# ↪      ⎠                                  2                             2      ↪
# ↪                                       dt                                     ↪
#
# ↪                                                2                 ⎛           ↪
# ↪               2                               d                  ⎜           ↪
# ↪    ⎛d        ⎞    l₁⋅l₃⋅m₃⋅cos(θ₁(t) - θ₃(t))⋅───(θ₃(t))   l₁⋅m₁⋅⎜- l₁⋅sin(θ ↪
# ↪ ))⋅⎜──(θ₃(t))⎟                                  2                ⎜           ↪
# ↪    ⎝dt       ⎠                                dt                 ⎝           ↪
# ↪ ─────────────── + ────────────────────────────────────── + ───────────────── ↪
# ↪                                     2                                        ↪
# ↪                                                                              ↪
#
# ↪        2                                    2                  2             ↪
# ↪       d                          ⎛d        ⎞                  d              ↪
# ↪ ₁(t))⋅───(θ₁(t)) - l₁⋅cos(θ₁(t))⋅⎜──(θ₁(t))⎟  - l₂⋅sin(θ₂(t))⋅───(θ₂(t)) - l ↪
# ↪         2                        ⎝dt       ⎠                    2            ↪
# ↪       dt                                                      dt             ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                         2                        2                           ↪
# ↪              ⎛d        ⎞                        d                            ↪
# ↪ ₂⋅cos(θ₂(t))⋅⎜──(θ₂(t))⎟  + l₄⋅sin(φ_D - θ₃(t))⋅───(θ₃(t)) - l₄⋅cos(φ_D - θ₃ ↪
# ↪              ⎝dt       ⎠                          2                          ↪
# ↪                                                 dt                           ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪      2                                                                       ↪
# ↪                                                                              ↪
#
# ↪                 2⎞                                                           ↪
# ↪      ⎛d        ⎞ ⎟                                                           ↪
# ↪ (t))⋅⎜──(θ₃(t))⎟ ⎟⋅sin(θ₁(t))                                                ↪
# ↪      ⎝dt       ⎠ ⎟                    ⎛                 2                    ↪
# ↪                  ⎠                    ⎜                d                     ↪
# ↪ ───────────────────────────── + l₁⋅m₂⋅⎜- l₁⋅sin(θ₁(t))⋅───(θ₁(t)) - l₁⋅cos(θ ↪
# ↪                                       ⎜                  2                   ↪
# ↪                                       ⎝                dt                    ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                  2                  2                                    2   ↪
# ↪       ⎛d        ⎞                  d                          ⎛d        ⎞    ↪
# ↪ ₁(t))⋅⎜──(θ₁(t))⎟  - l₂⋅sin(θ₂(t))⋅───(θ₂(t)) - l₂⋅cos(θ₂(t))⋅⎜──(θ₂(t))⎟  + ↪
# ↪       ⎝dt       ⎠                    2                        ⎝dt       ⎠    ↪
# ↪                                    dt                                        ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                       2                                          2⎞          ↪
# ↪                      d                                ⎛d        ⎞ ⎟          ↪
# ↪  l₄⋅sin(φ_D - θ₃(t))⋅───(θ₃(t)) - l₄⋅cos(φ_D - θ₃(t))⋅⎜──(θ₃(t))⎟ ⎟⋅sin(θ₁(t ↪
# ↪                        2                              ⎝dt       ⎠ ⎟          ↪
# ↪                      dt                                           ⎠          ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪            ⎛                 2                                    2          ↪
# ↪            ⎜                d                          ⎛d        ⎞           ↪
# ↪ )) + l₁⋅m₃⋅⎜- l₁⋅sin(θ₁(t))⋅───(θ₁(t)) - l₁⋅cos(θ₁(t))⋅⎜──(θ₁(t))⎟  - l₂⋅sin ↪
# ↪            ⎜                  2                        ⎝dt       ⎠           ↪
# ↪            ⎝                dt                                               ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪          2                                    2                        2     ↪
# ↪         d                          ⎛d        ⎞                        d      ↪
# ↪ (θ₂(t))⋅───(θ₂(t)) - l₂⋅cos(θ₂(t))⋅⎜──(θ₂(t))⎟  + l₄⋅sin(φ_D - θ₃(t))⋅───(θ₃ ↪
# ↪           2                        ⎝dt       ⎠                          2    ↪
# ↪         dt                                                            dt     ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                       2⎞                                     ↪
# ↪                            ⎛d        ⎞ ⎟                                     ↪
# ↪ (t)) - l₄⋅cos(φ_D - θ₃(t))⋅⎜──(θ₃(t))⎟ ⎟⋅sin(θ₁(t)) + l₁⋅μ₁(t)⋅cos(θ₁(t)) =  ↪
# ↪                            ⎝dt       ⎠ ⎟                                     ↪
# ↪                                        ⎠                                     ↪
#
# ↪
# ↪
# ↪
# ↪
# ↪
# ↪ 0
# ↪
# ↪

# %%
Eq(diff(diff(theta_1, t), t), simplify(solve(EOM_HS_1, diff(diff(theta_1, t), t))[0]))
# Out:
#                ⎛                                                               ↪
#                ⎜        d                 d                                    ↪
#              3⋅⎜- 4⋅b_B⋅──(θ₁(t)) + 4⋅b_B⋅──(θ₂(t)) - 2⋅g⋅l₁⋅m₁⋅sin(θ₁(t)) - 4 ↪
#  2             ⎜        dt                dt                                   ↪
# d              ⎝                                                               ↪
# ───(θ₁(t)) = ───────────────────────────────────────────────────────────────── ↪
#   2                                                                            ↪
# dt                                                                             ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ ⋅g⋅l₁⋅m₂⋅sin(θ₁(t)) - 4⋅g⋅l₁⋅m₃⋅sin(θ₁(t)) + 4⋅k_B⋅ψ_B - 4⋅k_B⋅θ₁(t) + 4⋅k_B ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                         2                                    ↪
# ↪            2                 ⎛d        ⎞        2                 ⎛d         ↪
# ↪ ⋅θ₂(t) + l₁ ⋅m₁⋅sin(2⋅θ₁(t))⋅⎜──(θ₁(t))⎟  + 2⋅l₁ ⋅m₂⋅sin(2⋅θ₁(t))⋅⎜──(θ₁(t)) ↪
# ↪                              ⎝dt       ⎠                          ⎝dt        ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪  2                                    2                                      ↪
# ↪ ⎞        2                 ⎛d        ⎞                                ⎛d     ↪
# ↪ ⎟  + 2⋅l₁ ⋅m₃⋅sin(2⋅θ₁(t))⋅⎜──(θ₁(t))⎟  + l₁⋅l₂⋅m₁⋅sin(θ₁(t) - θ₂(t))⋅⎜──(θ₂ ↪
# ↪ ⎠                          ⎝dt       ⎠                                ⎝dt    ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪      2                                          2                            ↪
# ↪     ⎞                                ⎛d        ⎞                             ↪
# ↪ (t))⎟  + l₁⋅l₂⋅m₁⋅sin(θ₁(t) + θ₂(t))⋅⎜──(θ₂(t))⎟  + l₁⋅l₂⋅m₁⋅cos(θ₁(t) - θ₂( ↪
# ↪     ⎠                                ⎝dt       ⎠                             ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪      2                                        2                              ↪
# ↪     d                                        d                               ↪
# ↪ t))⋅───(θ₂(t)) - l₁⋅l₂⋅m₁⋅cos(θ₁(t) + θ₂(t))⋅───(θ₂(t)) + 2⋅l₁⋅l₂⋅m₂⋅sin(θ₁( ↪
# ↪       2                                        2                             ↪
# ↪     dt                                       dt                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                        2                                  2                  ↪
# ↪             ⎛d        ⎞                                  d                   ↪
# ↪ t) + θ₂(t))⋅⎜──(θ₂(t))⎟  - 2⋅l₁⋅l₂⋅m₂⋅cos(θ₁(t) + θ₂(t))⋅───(θ₂(t)) - 2⋅l₁⋅l ↪
# ↪             ⎝dt       ⎠                                    2                 ↪
# ↪                                                          dt                  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                    2                                         ↪
# ↪                         ⎛d        ⎞                                  ⎛d      ↪
# ↪ ₂⋅m₃⋅sin(θ₁(t) - θ₂(t))⋅⎜──(θ₂(t))⎟  + 2⋅l₁⋅l₂⋅m₃⋅sin(θ₁(t) + θ₂(t))⋅⎜──(θ₂( ↪
# ↪                         ⎝dt       ⎠                                  ⎝dt     ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪     2                                  2                                     ↪
# ↪    ⎞                                  d                                      ↪
# ↪ t))⎟  - 2⋅l₁⋅l₂⋅m₃⋅cos(θ₁(t) - θ₂(t))⋅───(θ₂(t)) - 2⋅l₁⋅l₂⋅m₃⋅cos(θ₁(t) + θ₂ ↪
# ↪    ⎠                                    2                                    ↪
# ↪                                       dt                                     ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                          2 ⎛ ↪
# ↪                                                                      2⋅l₁ ⋅⎝ ↪
#
# ↪       2                                                    2                 ↪
# ↪      d                                          ⎛d        ⎞                  ↪
# ↪ (t))⋅───(θ₂(t)) - 2⋅l₁⋅l₃⋅m₃⋅sin(θ₁(t) - θ₃(t))⋅⎜──(θ₃(t))⎟  - 2⋅l₁⋅l₃⋅m₃⋅co ↪
# ↪        2                                        ⎝dt       ⎠                  ↪
# ↪      dt                                                                      ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪         2                       2                  2       ⎞                 ↪
# ↪ 3⋅m₁⋅cos (θ₁(t)) - m₁ + 6⋅m₂⋅cos (θ₁(t)) + 6⋅m₃⋅cos (θ₁(t))⎠                 ↪
#
# ↪                   2                                                          ↪
# ↪                  d                                               ⎛d        ⎞ ↪
# ↪ s(θ₁(t) - θ₃(t))⋅───(θ₃(t)) + l₁⋅l₄⋅m₁⋅sin(-φ_D + θ₁(t) + θ₃(t))⋅⎜──(θ₃(t))⎟ ↪
# ↪                    2                                             ⎝dt       ⎠ ↪
# ↪                  dt                                                          ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ 2                                                2                           ↪
# ↪                                       ⎛d        ⎞                            ↪
# ↪   + l₁⋅l₄⋅m₁⋅sin(φ_D + θ₁(t) - θ₃(t))⋅⎜──(θ₃(t))⎟  - l₁⋅l₄⋅m₁⋅cos(-φ_D + θ₁( ↪
# ↪                                       ⎝dt       ⎠                            ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪              2                                              2                ↪
# ↪             d                                              d                 ↪
# ↪ t) + θ₃(t))⋅───(θ₃(t)) + l₁⋅l₄⋅m₁⋅cos(φ_D + θ₁(t) - θ₃(t))⋅───(θ₃(t)) + 2⋅l₁ ↪
# ↪               2                                              2               ↪
# ↪             dt                                             dt                ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                             2                                ↪
# ↪                                  ⎛d        ⎞                                 ↪
# ↪ ⋅l₄⋅m₂⋅sin(-φ_D + θ₁(t) + θ₃(t))⋅⎜──(θ₃(t))⎟  + 2⋅l₁⋅l₄⋅m₂⋅sin(φ_D + θ₁(t) - ↪
# ↪                                  ⎝dt       ⎠                                 ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                    2                                         2               ↪
# ↪         ⎛d        ⎞                                         d                ↪
# ↪  θ₃(t))⋅⎜──(θ₃(t))⎟  - 2⋅l₁⋅l₄⋅m₂⋅cos(-φ_D + θ₁(t) + θ₃(t))⋅───(θ₃(t)) + 2⋅l ↪
# ↪         ⎝dt       ⎠                                           2              ↪
# ↪                                                             dt               ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                   2                                          ↪
# ↪                                  d                                           ↪
# ↪ ₁⋅l₄⋅m₂⋅cos(φ_D + θ₁(t) - θ₃(t))⋅───(θ₃(t)) + 2⋅l₁⋅l₄⋅m₃⋅sin(-φ_D + θ₁(t) +  ↪
# ↪                                    2                                         ↪
# ↪                                  dt                                          ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                   2                                                  2       ↪
# ↪        ⎛d        ⎞                                        ⎛d        ⎞        ↪
# ↪ θ₃(t))⋅⎜──(θ₃(t))⎟  + 2⋅l₁⋅l₄⋅m₃⋅sin(φ_D + θ₁(t) - θ₃(t))⋅⎜──(θ₃(t))⎟  - 2⋅l ↪
# ↪        ⎝dt       ⎠                                        ⎝dt       ⎠        ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                    2                                         ↪
# ↪                                   d                                          ↪
# ↪ ₁⋅l₄⋅m₃⋅cos(-φ_D + θ₁(t) + θ₃(t))⋅───(θ₃(t)) + 2⋅l₁⋅l₄⋅m₃⋅cos(φ_D + θ₁(t) -  ↪
# ↪                                     2                                        ↪
# ↪                                   dt                                         ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪         2                                ⎞
# ↪        d                                 ⎟
# ↪ θ₃(t))⋅───(θ₃(t)) - 4⋅l₁⋅μ₁(t)⋅cos(θ₁(t))⎟
# ↪          2                               ⎟
# ↪        dt                                ⎠
# ↪ ──────────────────────────────────────────
# ↪
# ↪

# %%
EOM_HS_2 = simplify(EOM_2.subs(y, y_HS) + mu_1 * l_2 * cos(theta_2))
Eq(EOM_HS_2, 0)
# Out:
#                                                                                ↪
#                                                                                ↪
#                                                                                ↪
#                                                                                ↪
#       d               d               d               d           g⋅l₂⋅m₂⋅sin( ↪
# - b_B⋅──(θ₁(t)) + b_B⋅──(θ₂(t)) + b_C⋅──(θ₂(t)) - b_C⋅──(θ₃(t)) + ──────────── ↪
#       dt              dt              dt              dt                  2    ↪
#                                                                                ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ θ₂(t))                                                                       ↪
# ↪ ────── + g⋅l₂⋅m₃⋅sin(θ₂(t)) + k_B⋅ψ_B - k_B⋅θ₁(t) + k_B⋅θ₂(t) - k_C⋅ψ_C + k_ ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                              2               ↪
# ↪                                                   ⎛d        ⎞    l₁⋅l₂⋅m₂⋅co ↪
# ↪                       l₁⋅l₂⋅m₂⋅sin(θ₁(t) - θ₂(t))⋅⎜──(θ₁(t))⎟                ↪
# ↪                                                   ⎝dt       ⎠                ↪
# ↪ C⋅θ₂(t) - k_C⋅θ₃(t) - ──────────────────────────────────────── + ─────────── ↪
# ↪                                          2                                   ↪
# ↪                                                                              ↪
#
# ↪                   2                                                          ↪
# ↪                  d                                                           ↪
# ↪ s(θ₁(t) - θ₂(t))⋅───(θ₁(t))                                                  ↪
# ↪                    2                                                 2       ↪
# ↪                  dt                                       ⎛d        ⎞        ↪
# ↪ ─────────────────────────── - l₁⋅l₂⋅m₃⋅sin(θ₁(t) - θ₂(t))⋅⎜──(θ₁(t))⎟  + l₁⋅ ↪
# ↪        2                                                  ⎝dt       ⎠        ↪
# ↪                                                                              ↪
#
# ↪                                               2                              ↪
# ↪                                         2    d                               ↪
# ↪                                       l₂ ⋅m₂⋅───(θ₂(t))                      ↪
# ↪                           2                    2                  2          ↪
# ↪                          d                   dt             2    d           ↪
# ↪ l₂⋅m₃⋅cos(θ₁(t) - θ₂(t))⋅───(θ₁(t)) + ───────────────── + l₂ ⋅m₃⋅───(θ₂(t))  ↪
# ↪                            2                  3                    2         ↪
# ↪                          dt                                      dt          ↪
#
# ↪                                                                           2  ↪
# ↪                                          2                               d   ↪
# ↪                               ⎛d        ⎞    l₂⋅l₃⋅m₃⋅cos(θ₂(t) - θ₃(t))⋅─── ↪
# ↪   l₂⋅l₃⋅m₃⋅sin(θ₂(t) - θ₃(t))⋅⎜──(θ₃(t))⎟                                  2 ↪
# ↪                               ⎝dt       ⎠                                dt  ↪
# ↪ + ──────────────────────────────────────── + ─────────────────────────────── ↪
# ↪                      2                                         2             ↪
# ↪                                                                              ↪
#
# ↪                 ⎛                 2                                    2     ↪
# ↪                 ⎜                d                          ⎛d        ⎞      ↪
# ↪ (θ₃(t))   l₂⋅m₂⋅⎜- l₁⋅sin(θ₁(t))⋅───(θ₁(t)) - l₁⋅cos(θ₁(t))⋅⎜──(θ₁(t))⎟  - l ↪
# ↪                 ⎜                  2                        ⎝dt       ⎠      ↪
# ↪                 ⎝                dt                                          ↪
# ↪ ─────── + ────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪               2                                    2                         ↪
# ↪              d                          ⎛d        ⎞                        d ↪
# ↪ ₂⋅sin(θ₂(t))⋅───(θ₂(t)) - l₂⋅cos(θ₂(t))⋅⎜──(θ₂(t))⎟  + l₄⋅sin(φ_D - θ₃(t))⋅─ ↪
# ↪                2                        ⎝dt       ⎠                          ↪
# ↪              dt                                                            d ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                 2                                            ↪
# ↪                                                                              ↪
#
# ↪ 2                                          2⎞                                ↪
# ↪                                 ⎛d        ⎞ ⎟                                ↪
# ↪ ──(θ₃(t)) - l₄⋅cos(φ_D - θ₃(t))⋅⎜──(θ₃(t))⎟ ⎟⋅sin(θ₂(t))                     ↪
# ↪  2                              ⎝dt       ⎠ ⎟                    ⎛           ↪
# ↪ t                                           ⎠                    ⎜           ↪
# ↪ ──────────────────────────────────────────────────────── + l₂⋅m₃⋅⎜- l₁⋅sin(θ ↪
# ↪                                                                  ⎜           ↪
# ↪                                                                  ⎝           ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪        2                                    2                  2             ↪
# ↪       d                          ⎛d        ⎞                  d              ↪
# ↪ ₁(t))⋅───(θ₁(t)) - l₁⋅cos(θ₁(t))⋅⎜──(θ₁(t))⎟  - l₂⋅sin(θ₂(t))⋅───(θ₂(t)) - l ↪
# ↪         2                        ⎝dt       ⎠                    2            ↪
# ↪       dt                                                      dt             ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                         2                        2                           ↪
# ↪              ⎛d        ⎞                        d                            ↪
# ↪ ₂⋅cos(θ₂(t))⋅⎜──(θ₂(t))⎟  + l₄⋅sin(φ_D - θ₃(t))⋅───(θ₃(t)) - l₄⋅cos(φ_D - θ₃ ↪
# ↪              ⎝dt       ⎠                          2                          ↪
# ↪                                                 dt                           ↪
#
# ↪
# ↪
# ↪
# ↪                 2⎞
# ↪      ⎛d        ⎞ ⎟
# ↪ (t))⋅⎜──(θ₃(t))⎟ ⎟⋅sin(θ₂(t)) + l₂⋅μ₁(t)⋅cos(θ₂(t)) = 0
# ↪      ⎝dt       ⎠ ⎟
# ↪                  ⎠

# %%
Eq(diff(diff(theta_2, t), t), simplify(solve(EOM_HS_2, diff(diff(theta_2, t), t))[0]))
# Out:
#                ⎛                                                               ↪
#                ⎜      d                 d                 d                 d  ↪
#              3⋅⎜4⋅b_B⋅──(θ₁(t)) - 4⋅b_B⋅──(θ₂(t)) - 4⋅b_C⋅──(θ₂(t)) + 4⋅b_C⋅── ↪
#  2             ⎜      dt                dt                dt                dt ↪
# d              ⎝                                                               ↪
# ───(θ₂(t)) = ───────────────────────────────────────────────────────────────── ↪
#   2                                                                            ↪
# dt                                                                             ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ (θ₃(t)) - 2⋅g⋅l₂⋅m₂⋅sin(θ₂(t)) - 4⋅g⋅l₂⋅m₃⋅sin(θ₂(t)) - 4⋅k_B⋅ψ_B + 4⋅k_B⋅θ₁ ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ (t) - 4⋅k_B⋅θ₂(t) + 4⋅k_C⋅ψ_C - 4⋅k_C⋅θ₂(t) + 4⋅k_C⋅θ₃(t) + l₁⋅l₂⋅m₂⋅sin(θ₁( ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                        2                                          2          ↪
# ↪             ⎛d        ⎞                                ⎛d        ⎞           ↪
# ↪ t) - θ₂(t))⋅⎜──(θ₁(t))⎟  + l₁⋅l₂⋅m₂⋅sin(θ₁(t) + θ₂(t))⋅⎜──(θ₁(t))⎟  - l₁⋅l₂⋅ ↪
# ↪             ⎝dt       ⎠                                ⎝dt       ⎠           ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                        2                                        2            ↪
# ↪                       d                                        d             ↪
# ↪ m₂⋅cos(θ₁(t) - θ₂(t))⋅───(θ₁(t)) - l₁⋅l₂⋅m₂⋅cos(θ₁(t) + θ₂(t))⋅───(θ₁(t)) +  ↪
# ↪                         2                                        2           ↪
# ↪                       dt                                       dt            ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                          2                                   ↪
# ↪                               ⎛d        ⎞                                  ⎛ ↪
# ↪ 2⋅l₁⋅l₂⋅m₃⋅sin(θ₁(t) - θ₂(t))⋅⎜──(θ₁(t))⎟  + 2⋅l₁⋅l₂⋅m₃⋅sin(θ₁(t) + θ₂(t))⋅⎜ ↪
# ↪                               ⎝dt       ⎠                                  ⎝ ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪           2                                  2                               ↪
# ↪ d        ⎞                                  d                                ↪
# ↪ ──(θ₁(t))⎟  - 2⋅l₁⋅l₂⋅m₃⋅cos(θ₁(t) - θ₂(t))⋅───(θ₁(t)) - 2⋅l₁⋅l₂⋅m₃⋅cos(θ₁(t ↪
# ↪ dt       ⎠                                    2                              ↪
# ↪                                             dt                               ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪             2                                          2                     ↪
# ↪            d              2                 ⎛d        ⎞        2             ↪
# ↪ ) + θ₂(t))⋅───(θ₁(t)) + l₂ ⋅m₂⋅sin(2⋅θ₂(t))⋅⎜──(θ₂(t))⎟  + 2⋅l₂ ⋅m₃⋅sin(2⋅θ₂ ↪
# ↪              2                              ⎝dt       ⎠                      ↪
# ↪            dt                                                                ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                     2 ⎛        2                       2       ⎞             ↪
# ↪                 2⋅l₂ ⋅⎝3⋅m₂⋅cos (θ₂(t)) - m₂ + 6⋅m₃⋅cos (θ₂(t))⎠             ↪
#
# ↪                 2                                            2               ↪
# ↪      ⎛d        ⎞                                  ⎛d        ⎞                ↪
# ↪ (t))⋅⎜──(θ₂(t))⎟  - 2⋅l₂⋅l₃⋅m₃⋅sin(θ₂(t) - θ₃(t))⋅⎜──(θ₃(t))⎟  - 2⋅l₂⋅l₃⋅m₃⋅ ↪
# ↪      ⎝dt       ⎠                                  ⎝dt       ⎠                ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                     2                                                        ↪
# ↪                    d                                               ⎛d        ↪
# ↪ cos(θ₂(t) - θ₃(t))⋅───(θ₃(t)) + l₂⋅l₄⋅m₂⋅sin(-φ_D + θ₂(t) + θ₃(t))⋅⎜──(θ₃(t) ↪
# ↪                      2                                             ⎝dt       ↪
# ↪                    dt                                                        ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪   2                                                2                         ↪
# ↪  ⎞                                      ⎛d        ⎞                          ↪
# ↪ )⎟  + l₂⋅l₄⋅m₂⋅sin(φ_D + θ₂(t) - θ₃(t))⋅⎜──(θ₃(t))⎟  - l₂⋅l₄⋅m₂⋅cos(-φ_D + θ ↪
# ↪  ⎠                                      ⎝dt       ⎠                          ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                2                                              2              ↪
# ↪               d                                              d               ↪
# ↪ ₂(t) + θ₃(t))⋅───(θ₃(t)) + l₂⋅l₄⋅m₂⋅cos(φ_D + θ₂(t) - θ₃(t))⋅───(θ₃(t)) + 2⋅ ↪
# ↪                 2                                              2             ↪
# ↪               dt                                             dt              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                               2                              ↪
# ↪                                    ⎛d        ⎞                               ↪
# ↪ l₂⋅l₄⋅m₃⋅sin(-φ_D + θ₂(t) + θ₃(t))⋅⎜──(θ₃(t))⎟  + 2⋅l₂⋅l₄⋅m₃⋅sin(φ_D + θ₂(t) ↪
# ↪                                    ⎝dt       ⎠                               ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                      2                                         2             ↪
# ↪           ⎛d        ⎞                                         d              ↪
# ↪  - θ₃(t))⋅⎜──(θ₃(t))⎟  - 2⋅l₂⋅l₄⋅m₃⋅cos(-φ_D + θ₂(t) + θ₃(t))⋅───(θ₃(t)) + 2 ↪
# ↪           ⎝dt       ⎠                                           2            ↪
# ↪                                                               dt             ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                     2                                ⎞
# ↪                                    d                                 ⎟
# ↪ ⋅l₂⋅l₄⋅m₃⋅cos(φ_D + θ₂(t) - θ₃(t))⋅───(θ₃(t)) - 4⋅l₂⋅μ₁(t)⋅cos(θ₂(t))⎟
# ↪                                      2                               ⎟
# ↪                                    dt                                ⎠
# ↪ ──────────────────────────────────────────────────────────────────────
# ↪
# ↪

# %%
EOM_HS_3 = simplify(EOM_3.subs(y, y_HS) + mu_1 * l_4 * cos(phi_D - theta_3))
Eq(EOM_HS_1, 0)
# Out:
#                                                                                ↪
#                                                                                ↪
#                                                                                ↪
#                                                                                ↪
#     d               d           g⋅l₁⋅m₁⋅sin(θ₁(t))                             ↪
# b_B⋅──(θ₁(t)) - b_B⋅──(θ₂(t)) + ────────────────── + g⋅l₁⋅m₂⋅sin(θ₁(t)) + g⋅l₁ ↪
#     dt              dt                  2                                      ↪
#                                                                                ↪
#
# ↪                                                            2                 ↪
# ↪                                                      2    d                  ↪
# ↪                                                    l₁ ⋅m₁⋅───(θ₁(t))         ↪
# ↪                                                             2                ↪
# ↪                                                           dt             2   ↪
# ↪ ⋅m₃⋅sin(θ₁(t)) - k_B⋅ψ_B + k_B⋅θ₁(t) - k_B⋅θ₂(t) + ───────────────── + l₁ ⋅m ↪
# ↪                                                            3                 ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                                           2  ↪
# ↪                                                                ⎛d        ⎞   ↪
# ↪    2                   2           l₁⋅l₂⋅m₂⋅sin(θ₁(t) - θ₂(t))⋅⎜──(θ₂(t))⎟   ↪
# ↪   d              2    d                                        ⎝dt       ⎠   ↪
# ↪ ₂⋅───(θ₁(t)) + l₁ ⋅m₃⋅───(θ₁(t)) + ────────────────────────────────────────  ↪
# ↪     2                   2                             2                      ↪
# ↪   dt                  dt                                                     ↪
#
# ↪                                2                                             ↪
# ↪                               d                                              ↪
# ↪   l₁⋅l₂⋅m₂⋅cos(θ₁(t) - θ₂(t))⋅───(θ₂(t))                                     ↪
# ↪                                 2                                            ↪
# ↪                               dt                                       ⎛d    ↪
# ↪ + ────────────────────────────────────── + l₁⋅l₂⋅m₃⋅sin(θ₁(t) - θ₂(t))⋅⎜──(θ ↪
# ↪                     2                                                  ⎝dt   ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪       2                                2           l₁⋅l₃⋅m₃⋅sin(θ₁(t) - θ₃(t ↪
# ↪      ⎞                                d                                      ↪
# ↪ ₂(t))⎟  + l₁⋅l₂⋅m₃⋅cos(θ₁(t) - θ₂(t))⋅───(θ₂(t)) + ───────────────────────── ↪
# ↪      ⎠                                  2                             2      ↪
# ↪                                       dt                                     ↪
#
# ↪                                                2                 ⎛           ↪
# ↪               2                               d                  ⎜           ↪
# ↪    ⎛d        ⎞    l₁⋅l₃⋅m₃⋅cos(θ₁(t) - θ₃(t))⋅───(θ₃(t))   l₁⋅m₁⋅⎜- l₁⋅sin(θ ↪
# ↪ ))⋅⎜──(θ₃(t))⎟                                  2                ⎜           ↪
# ↪    ⎝dt       ⎠                                dt                 ⎝           ↪
# ↪ ─────────────── + ────────────────────────────────────── + ───────────────── ↪
# ↪                                     2                                        ↪
# ↪                                                                              ↪
#
# ↪        2                                    2                  2             ↪
# ↪       d                          ⎛d        ⎞                  d              ↪
# ↪ ₁(t))⋅───(θ₁(t)) - l₁⋅cos(θ₁(t))⋅⎜──(θ₁(t))⎟  - l₂⋅sin(θ₂(t))⋅───(θ₂(t)) - l ↪
# ↪         2                        ⎝dt       ⎠                    2            ↪
# ↪       dt                                                      dt             ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                         2                        2                           ↪
# ↪              ⎛d        ⎞                        d                            ↪
# ↪ ₂⋅cos(θ₂(t))⋅⎜──(θ₂(t))⎟  + l₄⋅sin(φ_D - θ₃(t))⋅───(θ₃(t)) - l₄⋅cos(φ_D - θ₃ ↪
# ↪              ⎝dt       ⎠                          2                          ↪
# ↪                                                 dt                           ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪      2                                                                       ↪
# ↪                                                                              ↪
#
# ↪                 2⎞                                                           ↪
# ↪      ⎛d        ⎞ ⎟                                                           ↪
# ↪ (t))⋅⎜──(θ₃(t))⎟ ⎟⋅sin(θ₁(t))                                                ↪
# ↪      ⎝dt       ⎠ ⎟                    ⎛                 2                    ↪
# ↪                  ⎠                    ⎜                d                     ↪
# ↪ ───────────────────────────── + l₁⋅m₂⋅⎜- l₁⋅sin(θ₁(t))⋅───(θ₁(t)) - l₁⋅cos(θ ↪
# ↪                                       ⎜                  2                   ↪
# ↪                                       ⎝                dt                    ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                  2                  2                                    2   ↪
# ↪       ⎛d        ⎞                  d                          ⎛d        ⎞    ↪
# ↪ ₁(t))⋅⎜──(θ₁(t))⎟  - l₂⋅sin(θ₂(t))⋅───(θ₂(t)) - l₂⋅cos(θ₂(t))⋅⎜──(θ₂(t))⎟  + ↪
# ↪       ⎝dt       ⎠                    2                        ⎝dt       ⎠    ↪
# ↪                                    dt                                        ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                       2                                          2⎞          ↪
# ↪                      d                                ⎛d        ⎞ ⎟          ↪
# ↪  l₄⋅sin(φ_D - θ₃(t))⋅───(θ₃(t)) - l₄⋅cos(φ_D - θ₃(t))⋅⎜──(θ₃(t))⎟ ⎟⋅sin(θ₁(t ↪
# ↪                        2                              ⎝dt       ⎠ ⎟          ↪
# ↪                      dt                                           ⎠          ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪            ⎛                 2                                    2          ↪
# ↪            ⎜                d                          ⎛d        ⎞           ↪
# ↪ )) + l₁⋅m₃⋅⎜- l₁⋅sin(θ₁(t))⋅───(θ₁(t)) - l₁⋅cos(θ₁(t))⋅⎜──(θ₁(t))⎟  - l₂⋅sin ↪
# ↪            ⎜                  2                        ⎝dt       ⎠           ↪
# ↪            ⎝                dt                                               ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪          2                                    2                        2     ↪
# ↪         d                          ⎛d        ⎞                        d      ↪
# ↪ (θ₂(t))⋅───(θ₂(t)) - l₂⋅cos(θ₂(t))⋅⎜──(θ₂(t))⎟  + l₄⋅sin(φ_D - θ₃(t))⋅───(θ₃ ↪
# ↪           2                        ⎝dt       ⎠                          2    ↪
# ↪         dt                                                            dt     ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                       2⎞                                     ↪
# ↪                            ⎛d        ⎞ ⎟                                     ↪
# ↪ (t)) - l₄⋅cos(φ_D - θ₃(t))⋅⎜──(θ₃(t))⎟ ⎟⋅sin(θ₁(t)) + l₁⋅μ₁(t)⋅cos(θ₁(t)) =  ↪
# ↪                            ⎝dt       ⎠ ⎟                                     ↪
# ↪                                        ⎠                                     ↪
#
# ↪
# ↪
# ↪
# ↪
# ↪
# ↪ 0
# ↪
# ↪

# %%
Eq(diff(diff(theta_3, t), t), simplify(solve(EOM_HS_3, diff(diff(theta_3, t), t))[0]))
# Out:
#                ⎛                                                               ↪
#                ⎜      d                 d                                      ↪
#              3⋅⎜2⋅b_C⋅──(θ₂(t)) - 2⋅b_C⋅──(θ₃(t)) - g⋅l₃⋅m₃⋅sin(θ₃(t)) - 2⋅k_C ↪
#  2             ⎜      dt                dt                                     ↪
# d              ⎝                                                               ↪
# ───(θ₃(t)) = ───────────────────────────────────────────────────────────────── ↪
#   2                                                                            ↪
# dt                                                                             ↪
#
# ↪                                                                              ↪
# ↪                                                                   ⎛d         ↪
# ↪ ⋅ψ_C + 2⋅k_C⋅θ₂(t) - 2⋅k_C⋅θ₃(t) + l₁⋅l₃⋅m₃⋅sin(θ₁(t))⋅cos(θ₃(t))⋅⎜──(θ₁(t)) ↪
# ↪                                                                   ⎝dt        ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪  2                                   2                                       ↪
# ↪ ⎞                                   d                                        ↪
# ↪ ⎟  - l₁⋅l₃⋅m₃⋅cos(θ₁(t))⋅cos(θ₃(t))⋅───(θ₁(t)) + l₂⋅l₃⋅m₃⋅sin(θ₂(t))⋅cos(θ₃( ↪
# ↪ ⎠                                     2                                      ↪
# ↪                                     dt                                       ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                l₃⋅m₃⋅(2⋅l₃ + 3⋅l₄⋅sin(φ_D - θ₃(t))⋅sin(θ₃(t)))               ↪
# ↪                                                                              ↪
#
# ↪                2                                   2                         ↪
# ↪     ⎛d        ⎞                                   d                          ↪
# ↪ t))⋅⎜──(θ₂(t))⎟  - l₂⋅l₃⋅m₃⋅cos(θ₂(t))⋅cos(θ₃(t))⋅───(θ₂(t)) + l₃⋅l₄⋅m₃⋅sin( ↪
# ↪     ⎝dt       ⎠                                     2                        ↪
# ↪                                                   dt                         ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                    2                              ⎞
# ↪                         ⎛d        ⎞                               ⎟
# ↪ θ₃(t))⋅cos(φ_D - θ₃(t))⋅⎜──(θ₃(t))⎟  - 2⋅l₄⋅μ₁(t)⋅cos(φ_D - θ₃(t))⎟
# ↪                         ⎝dt       ⎠                               ⎟
# ↪                                                                   ⎠
# ↪ ───────────────────────────────────────────────────────────────────
# ↪
# ↪

# %%
Eq(const_HS_u_E, 0)
# Out:
#               d                         d                               d      ↪
# l₁⋅cos(θ₁(t))⋅──(θ₁(t)) + l₂⋅cos(θ₂(t))⋅──(θ₂(t)) + l₄⋅cos(φ_D - θ₃(t))⋅──(θ₃( ↪
#               dt                        dt                              dt     ↪
#
# ↪
# ↪ t)) + v = 0
# ↪

# %% [markdown]
# Toe Lift-Off Equations of Motion

# %%
EOM_TLO_y = simplify(EOM_y.subs(y, y_TLO))
Eq(EOM_TLO_y, 0)
# Out:
#                             ⎛                 2                                ↪
#                             ⎜                d                          ⎛d     ↪
#                          m₁⋅⎜- l₁⋅sin(θ₁(t))⋅───(θ₁(t)) - l₁⋅cos(θ₁(t))⋅⎜──(θ₁ ↪
#                             ⎜                  2                        ⎝dt    ↪
#                             ⎝                dt                                ↪
# g⋅(m₁ + m₂ + m₃ + m_A) + ───────────────────────────────────────────────────── ↪
#                                                                                ↪
#
# ↪      2                    2                                      2           ↪
# ↪     ⎞                    d                            ⎛d        ⎞            ↪
# ↪ (t))⎟  - 2⋅l₂⋅sin(θ₂(t))⋅───(θ₂(t)) - 2⋅l₂⋅cos(θ₂(t))⋅⎜──(θ₂(t))⎟  - 2⋅l₃⋅si ↪
# ↪     ⎠                      2                          ⎝dt       ⎠            ↪
# ↪                          dt                                                  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                     2                                        ↪
#
# ↪           2                                      2⎞      ⎛                 2 ↪
# ↪          d                            ⎛d        ⎞ ⎟      ⎜                d  ↪
# ↪ n(θ₃(t))⋅───(θ₃(t)) - 2⋅l₃⋅cos(θ₃(t))⋅⎜──(θ₃(t))⎟ ⎟   m₂⋅⎜- l₂⋅sin(θ₂(t))⋅── ↪
# ↪            2                          ⎝dt       ⎠ ⎟      ⎜                   ↪
# ↪          dt                                       ⎠      ⎝                dt ↪
# ↪ ─────────────────────────────────────────────────── + ────────────────────── ↪
# ↪                                                                              ↪
#
# ↪                                     2                    2                   ↪
# ↪                          ⎛d        ⎞                    d                    ↪
# ↪ ─(θ₂(t)) - l₂⋅cos(θ₂(t))⋅⎜──(θ₂(t))⎟  - 2⋅l₃⋅sin(θ₃(t))⋅───(θ₃(t)) - 2⋅l₃⋅co ↪
# ↪ 2                        ⎝dt       ⎠                      2                  ↪
# ↪                                                         dt                   ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                      2                                       ↪
#
# ↪                     2⎞      ⎛                 2                              ↪
# ↪          ⎛d        ⎞ ⎟      ⎜                d                          ⎛d   ↪
# ↪ s(θ₃(t))⋅⎜──(θ₃(t))⎟ ⎟   m₃⋅⎜- l₃⋅sin(θ₃(t))⋅───(θ₃(t)) - l₃⋅cos(θ₃(t))⋅⎜──( ↪
# ↪          ⎝dt       ⎠ ⎟      ⎜                  2                        ⎝dt  ↪
# ↪                      ⎠      ⎝                dt                              ↪
# ↪ ────────────────────── + ─────────────────────────────────────────────────── ↪
# ↪                                                       2                      ↪
#
# ↪        2⎞
# ↪       ⎞ ⎟
# ↪ θ₃(t))⎟ ⎟
# ↪       ⎠ ⎟
# ↪         ⎠
# ↪ ───────── = 0
# ↪

# %%
EOM_TLO_1 = simplify(EOM_1.subs(y, y_TLO) + mu_1 * l_1 * cos(theta_1))
Eq(EOM_TLO_1, 0)
# Out:
#                                                                                ↪
#                                                                                ↪
#                                                                                ↪
#                                                                                ↪
#     d               d           g⋅l₁⋅m₁⋅sin(θ₁(t))                             ↪
# b_B⋅──(θ₁(t)) - b_B⋅──(θ₂(t)) + ────────────────── + g⋅l₁⋅m₂⋅sin(θ₁(t)) + g⋅l₁ ↪
#     dt              dt                  2                                      ↪
#                                                                                ↪
#
# ↪                                                            2                 ↪
# ↪                                                      2    d                  ↪
# ↪                                                    l₁ ⋅m₁⋅───(θ₁(t))         ↪
# ↪                                                             2                ↪
# ↪                                                           dt             2   ↪
# ↪ ⋅m₃⋅sin(θ₁(t)) - k_B⋅ψ_B + k_B⋅θ₁(t) - k_B⋅θ₂(t) + ───────────────── + l₁ ⋅m ↪
# ↪                                                            3                 ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                                           2  ↪
# ↪                                                                ⎛d        ⎞   ↪
# ↪    2                   2           l₁⋅l₂⋅m₂⋅sin(θ₁(t) - θ₂(t))⋅⎜──(θ₂(t))⎟   ↪
# ↪   d              2    d                                        ⎝dt       ⎠   ↪
# ↪ ₂⋅───(θ₁(t)) + l₁ ⋅m₃⋅───(θ₁(t)) + ────────────────────────────────────────  ↪
# ↪     2                   2                             2                      ↪
# ↪   dt                  dt                                                     ↪
#
# ↪                                2                                             ↪
# ↪                               d                                              ↪
# ↪   l₁⋅l₂⋅m₂⋅cos(θ₁(t) - θ₂(t))⋅───(θ₂(t))                                     ↪
# ↪                                 2                                            ↪
# ↪                               dt                                       ⎛d    ↪
# ↪ + ────────────────────────────────────── + l₁⋅l₂⋅m₃⋅sin(θ₁(t) - θ₂(t))⋅⎜──(θ ↪
# ↪                     2                                                  ⎝dt   ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪       2                                2           l₁⋅l₃⋅m₃⋅sin(θ₁(t) - θ₃(t ↪
# ↪      ⎞                                d                                      ↪
# ↪ ₂(t))⎟  + l₁⋅l₂⋅m₃⋅cos(θ₁(t) - θ₂(t))⋅───(θ₂(t)) + ───────────────────────── ↪
# ↪      ⎠                                  2                             2      ↪
# ↪                                       dt                                     ↪
#
# ↪                                                2                 ⎛           ↪
# ↪               2                               d                  ⎜           ↪
# ↪    ⎛d        ⎞    l₁⋅l₃⋅m₃⋅cos(θ₁(t) - θ₃(t))⋅───(θ₃(t))   l₁⋅m₁⋅⎜- l₁⋅sin(θ ↪
# ↪ ))⋅⎜──(θ₃(t))⎟                                  2                ⎜           ↪
# ↪    ⎝dt       ⎠                                dt                 ⎝           ↪
# ↪ ─────────────── + ────────────────────────────────────── + ───────────────── ↪
# ↪                                     2                                        ↪
# ↪                                                                              ↪
#
# ↪        2                                    2                  2             ↪
# ↪       d                          ⎛d        ⎞                  d              ↪
# ↪ ₁(t))⋅───(θ₁(t)) - l₁⋅cos(θ₁(t))⋅⎜──(θ₁(t))⎟  - l₂⋅sin(θ₂(t))⋅───(θ₂(t)) - l ↪
# ↪         2                        ⎝dt       ⎠                    2            ↪
# ↪       dt                                                      dt             ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                            2 ↪
# ↪                                                                              ↪
#
# ↪                         2                  2                                 ↪
# ↪              ⎛d        ⎞                  d                          ⎛d      ↪
# ↪ ₂⋅cos(θ₂(t))⋅⎜──(θ₂(t))⎟  - l₃⋅sin(θ₃(t))⋅───(θ₃(t)) - l₃⋅cos(θ₃(t))⋅⎜──(θ₃( ↪
# ↪              ⎝dt       ⎠                    2                        ⎝dt     ↪
# ↪                                           dt                                 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪     2⎞                                                                       ↪
# ↪    ⎞ ⎟                                                                       ↪
# ↪ t))⎟ ⎟⋅sin(θ₁(t))                                                            ↪
# ↪    ⎠ ⎟                    ⎛                 2                                ↪
# ↪      ⎠                    ⎜                d                          ⎛d     ↪
# ↪ ───────────────── + l₁⋅m₂⋅⎜- l₁⋅sin(θ₁(t))⋅───(θ₁(t)) - l₁⋅cos(θ₁(t))⋅⎜──(θ₁ ↪
# ↪                           ⎜                  2                        ⎝dt    ↪
# ↪                           ⎝                dt                                ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪      2                  2                                    2               ↪
# ↪     ⎞                  d                          ⎛d        ⎞                ↪
# ↪ (t))⎟  - l₂⋅sin(θ₂(t))⋅───(θ₂(t)) - l₂⋅cos(θ₂(t))⋅⎜──(θ₂(t))⎟  - l₃⋅sin(θ₃(t ↪
# ↪     ⎠                    2                        ⎝dt       ⎠                ↪
# ↪                        dt                                                    ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪     2                                    2⎞                    ⎛             ↪
# ↪    d                          ⎛d        ⎞ ⎟                    ⎜             ↪
# ↪ ))⋅───(θ₃(t)) - l₃⋅cos(θ₃(t))⋅⎜──(θ₃(t))⎟ ⎟⋅sin(θ₁(t)) + l₁⋅m₃⋅⎜- l₁⋅sin(θ₁( ↪
# ↪      2                        ⎝dt       ⎠ ⎟                    ⎜             ↪
# ↪    dt                                     ⎠                    ⎝             ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪      2                                    2                  2               ↪
# ↪     d                          ⎛d        ⎞                  d                ↪
# ↪ t))⋅───(θ₁(t)) - l₁⋅cos(θ₁(t))⋅⎜──(θ₁(t))⎟  - l₂⋅sin(θ₂(t))⋅───(θ₂(t)) - l₂⋅ ↪
# ↪       2                        ⎝dt       ⎠                    2              ↪
# ↪     dt                                                      dt               ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                       2                  2                                   ↪
# ↪            ⎛d        ⎞                  d                          ⎛d        ↪
# ↪ cos(θ₂(t))⋅⎜──(θ₂(t))⎟  - l₃⋅sin(θ₃(t))⋅───(θ₃(t)) - l₃⋅cos(θ₃(t))⋅⎜──(θ₃(t) ↪
# ↪            ⎝dt       ⎠                    2                        ⎝dt       ↪
# ↪                                         dt                                   ↪
#
# ↪
# ↪
# ↪
# ↪   2⎞
# ↪  ⎞ ⎟
# ↪ )⎟ ⎟⋅sin(θ₁(t)) + l₁⋅μ₁(t)⋅cos(θ₁(t)) = 0
# ↪  ⎠ ⎟
# ↪    ⎠

# %%
Eq(diff(diff(theta_1, t), t), simplify(solve(EOM_TLO_1, diff(diff(theta_1, t), t))[0]))
# Out:
#                ⎛                                                               ↪
#                ⎜        d                 d                                    ↪
#              3⋅⎜- 4⋅b_B⋅──(θ₁(t)) + 4⋅b_B⋅──(θ₂(t)) - 2⋅g⋅l₁⋅m₁⋅sin(θ₁(t)) - 4 ↪
#  2             ⎜        dt                dt                                   ↪
# d              ⎝                                                               ↪
# ───(θ₁(t)) = ───────────────────────────────────────────────────────────────── ↪
#   2                                                                            ↪
# dt                                                                             ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ ⋅g⋅l₁⋅m₂⋅sin(θ₁(t)) - 4⋅g⋅l₁⋅m₃⋅sin(θ₁(t)) + 4⋅k_B⋅ψ_B - 4⋅k_B⋅θ₁(t) + 4⋅k_B ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                         2                                    ↪
# ↪            2                 ⎛d        ⎞        2                 ⎛d         ↪
# ↪ ⋅θ₂(t) + l₁ ⋅m₁⋅sin(2⋅θ₁(t))⋅⎜──(θ₁(t))⎟  + 2⋅l₁ ⋅m₂⋅sin(2⋅θ₁(t))⋅⎜──(θ₁(t)) ↪
# ↪                              ⎝dt       ⎠                          ⎝dt        ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪  2                                    2                                      ↪
# ↪ ⎞        2                 ⎛d        ⎞                                ⎛d     ↪
# ↪ ⎟  + 2⋅l₁ ⋅m₃⋅sin(2⋅θ₁(t))⋅⎜──(θ₁(t))⎟  + l₁⋅l₂⋅m₁⋅sin(θ₁(t) - θ₂(t))⋅⎜──(θ₂ ↪
# ↪ ⎠                          ⎝dt       ⎠                                ⎝dt    ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪      2                                          2                            ↪
# ↪     ⎞                                ⎛d        ⎞                             ↪
# ↪ (t))⎟  + l₁⋅l₂⋅m₁⋅sin(θ₁(t) + θ₂(t))⋅⎜──(θ₂(t))⎟  + l₁⋅l₂⋅m₁⋅cos(θ₁(t) - θ₂( ↪
# ↪     ⎠                                ⎝dt       ⎠                             ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪      2                                        2                              ↪
# ↪     d                                        d                               ↪
# ↪ t))⋅───(θ₂(t)) - l₁⋅l₂⋅m₁⋅cos(θ₁(t) + θ₂(t))⋅───(θ₂(t)) + 2⋅l₁⋅l₂⋅m₂⋅sin(θ₁( ↪
# ↪       2                                        2                             ↪
# ↪     dt                                       dt                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                        2                                  2                  ↪
# ↪             ⎛d        ⎞                                  d                   ↪
# ↪ t) + θ₂(t))⋅⎜──(θ₂(t))⎟  - 2⋅l₁⋅l₂⋅m₂⋅cos(θ₁(t) + θ₂(t))⋅───(θ₂(t)) - 2⋅l₁⋅l ↪
# ↪             ⎝dt       ⎠                                    2                 ↪
# ↪                                                          dt                  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                    2                                         ↪
# ↪                         ⎛d        ⎞                                  ⎛d      ↪
# ↪ ₂⋅m₃⋅sin(θ₁(t) - θ₂(t))⋅⎜──(θ₂(t))⎟  + 2⋅l₁⋅l₂⋅m₃⋅sin(θ₁(t) + θ₂(t))⋅⎜──(θ₂( ↪
# ↪                         ⎝dt       ⎠                                  ⎝dt     ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                       2 ⎛        2                       2                   ↪
# ↪                   2⋅l₁ ⋅⎝3⋅m₁⋅cos (θ₁(t)) - m₁ + 6⋅m₂⋅cos (θ₁(t)) + 6⋅m₃⋅cos ↪
#
# ↪     2                                  2                                     ↪
# ↪    ⎞                                  d                                      ↪
# ↪ t))⎟  - 2⋅l₁⋅l₂⋅m₃⋅cos(θ₁(t) - θ₂(t))⋅───(θ₂(t)) - 2⋅l₁⋅l₂⋅m₃⋅cos(θ₁(t) + θ₂ ↪
# ↪    ⎠                                    2                                    ↪
# ↪                                       dt                                     ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪ 2       ⎞                                                                    ↪
# ↪  (θ₁(t))⎠                                                                    ↪
#
# ↪       2                                                  2                   ↪
# ↪      d                                        ⎛d        ⎞                    ↪
# ↪ (t))⋅───(θ₂(t)) + l₁⋅l₃⋅m₁⋅sin(θ₁(t) - θ₃(t))⋅⎜──(θ₃(t))⎟  + l₁⋅l₃⋅m₁⋅sin(θ₁ ↪
# ↪        2                                      ⎝dt       ⎠                    ↪
# ↪      dt                                                                      ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                         2                                2                   ↪
# ↪              ⎛d        ⎞                                d                    ↪
# ↪ (t) + θ₃(t))⋅⎜──(θ₃(t))⎟  + l₁⋅l₃⋅m₁⋅cos(θ₁(t) - θ₃(t))⋅───(θ₃(t)) - l₁⋅l₃⋅m ↪
# ↪              ⎝dt       ⎠                                  2                  ↪
# ↪                                                         dt                   ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                       2                                                    2 ↪
# ↪                      d                                          ⎛d        ⎞  ↪
# ↪ ₁⋅cos(θ₁(t) + θ₃(t))⋅───(θ₃(t)) + 2⋅l₁⋅l₃⋅m₂⋅sin(θ₁(t) - θ₃(t))⋅⎜──(θ₃(t))⎟  ↪
# ↪                        2                                        ⎝dt       ⎠  ↪
# ↪                      dt                                                      ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                             2                                ↪
# ↪                                  ⎛d        ⎞                                 ↪
# ↪  + 2⋅l₁⋅l₃⋅m₂⋅sin(θ₁(t) + θ₃(t))⋅⎜──(θ₃(t))⎟  + 2⋅l₁⋅l₃⋅m₂⋅cos(θ₁(t) - θ₃(t) ↪
# ↪                                  ⎝dt       ⎠                                 ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪    2                                          2                              ↪
# ↪   d                                          d                               ↪
# ↪ )⋅───(θ₃(t)) - 2⋅l₁⋅l₃⋅m₂⋅cos(θ₁(t) + θ₃(t))⋅───(θ₃(t)) + 2⋅l₁⋅l₃⋅m₃⋅sin(θ₁( ↪
# ↪     2                                          2                             ↪
# ↪   dt                                         dt                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                        2                                  2                  ↪
# ↪             ⎛d        ⎞                                  d                   ↪
# ↪ t) + θ₃(t))⋅⎜──(θ₃(t))⎟  - 2⋅l₁⋅l₃⋅m₃⋅cos(θ₁(t) + θ₃(t))⋅───(θ₃(t)) - 4⋅l₁⋅μ ↪
# ↪             ⎝dt       ⎠                                    2                 ↪
# ↪                                                          dt                  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                ⎞
# ↪                ⎟
# ↪ ₁(t)⋅cos(θ₁(t))⎟
# ↪                ⎟
# ↪                ⎠
# ↪ ────────────────
# ↪
# ↪

# %%
EOM_TLO_2 = simplify(EOM_2.subs(y, y_TLO) + mu_1 * l_2 * cos(theta_2))
Eq(EOM_TLO_2, 0)
# Out:
#                                                                                ↪
#                                                                                ↪
#                                                                                ↪
#                                                                                ↪
#       d               d               d               d           g⋅l₂⋅m₂⋅sin( ↪
# - b_B⋅──(θ₁(t)) + b_B⋅──(θ₂(t)) + b_C⋅──(θ₂(t)) - b_C⋅──(θ₃(t)) + ──────────── ↪
#       dt              dt              dt              dt                  2    ↪
#                                                                                ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ θ₂(t))                                                                       ↪
# ↪ ────── + g⋅l₂⋅m₃⋅sin(θ₂(t)) + k_B⋅ψ_B - k_B⋅θ₁(t) + k_B⋅θ₂(t) - k_C⋅ψ_C + k_ ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                              2               ↪
# ↪                                                   ⎛d        ⎞    l₁⋅l₂⋅m₂⋅co ↪
# ↪                       l₁⋅l₂⋅m₂⋅sin(θ₁(t) - θ₂(t))⋅⎜──(θ₁(t))⎟                ↪
# ↪                                                   ⎝dt       ⎠                ↪
# ↪ C⋅θ₂(t) - k_C⋅θ₃(t) - ──────────────────────────────────────── + ─────────── ↪
# ↪                                          2                                   ↪
# ↪                                                                              ↪
#
# ↪                   2                                                          ↪
# ↪                  d                                                           ↪
# ↪ s(θ₁(t) - θ₂(t))⋅───(θ₁(t))                                                  ↪
# ↪                    2                                                 2       ↪
# ↪                  dt                                       ⎛d        ⎞        ↪
# ↪ ─────────────────────────── - l₁⋅l₂⋅m₃⋅sin(θ₁(t) - θ₂(t))⋅⎜──(θ₁(t))⎟  + l₁⋅ ↪
# ↪        2                                                  ⎝dt       ⎠        ↪
# ↪                                                                              ↪
#
# ↪                                               2                              ↪
# ↪                                         2    d                               ↪
# ↪                                       l₂ ⋅m₂⋅───(θ₂(t))                      ↪
# ↪                           2                    2                  2          ↪
# ↪                          d                   dt             2    d           ↪
# ↪ l₂⋅m₃⋅cos(θ₁(t) - θ₂(t))⋅───(θ₁(t)) + ───────────────── + l₂ ⋅m₃⋅───(θ₂(t))  ↪
# ↪                            2                  3                    2         ↪
# ↪                          dt                                      dt          ↪
#
# ↪                                                                           2  ↪
# ↪                                          2                               d   ↪
# ↪                               ⎛d        ⎞    l₂⋅l₃⋅m₃⋅cos(θ₂(t) - θ₃(t))⋅─── ↪
# ↪   l₂⋅l₃⋅m₃⋅sin(θ₂(t) - θ₃(t))⋅⎜──(θ₃(t))⎟                                  2 ↪
# ↪                               ⎝dt       ⎠                                dt  ↪
# ↪ + ──────────────────────────────────────── + ─────────────────────────────── ↪
# ↪                      2                                         2             ↪
# ↪                                                                              ↪
#
# ↪                 ⎛                 2                                    2     ↪
# ↪                 ⎜                d                          ⎛d        ⎞      ↪
# ↪ (θ₃(t))   l₂⋅m₂⋅⎜- l₁⋅sin(θ₁(t))⋅───(θ₁(t)) - l₁⋅cos(θ₁(t))⋅⎜──(θ₁(t))⎟  - l ↪
# ↪                 ⎜                  2                        ⎝dt       ⎠      ↪
# ↪                 ⎝                dt                                          ↪
# ↪ ─────── + ────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪               2                                    2                  2      ↪
# ↪              d                          ⎛d        ⎞                  d       ↪
# ↪ ₂⋅sin(θ₂(t))⋅───(θ₂(t)) - l₂⋅cos(θ₂(t))⋅⎜──(θ₂(t))⎟  - l₃⋅sin(θ₃(t))⋅───(θ₃( ↪
# ↪                2                        ⎝dt       ⎠                    2     ↪
# ↪              dt                                                      dt      ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                           2                                                  ↪
# ↪                                                                              ↪
#
# ↪                                2⎞                                            ↪
# ↪                     ⎛d        ⎞ ⎟                                            ↪
# ↪ t)) - l₃⋅cos(θ₃(t))⋅⎜──(θ₃(t))⎟ ⎟⋅sin(θ₂(t))                                 ↪
# ↪                     ⎝dt       ⎠ ⎟                    ⎛                 2     ↪
# ↪                                 ⎠                    ⎜                d      ↪
# ↪ ──────────────────────────────────────────── + l₂⋅m₃⋅⎜- l₁⋅sin(θ₁(t))⋅───(θ₁ ↪
# ↪                                                      ⎜                  2    ↪
# ↪                                                      ⎝                dt     ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                 2                  2                         ↪
# ↪                      ⎛d        ⎞                  d                          ↪
# ↪ (t)) - l₁⋅cos(θ₁(t))⋅⎜──(θ₁(t))⎟  - l₂⋅sin(θ₂(t))⋅───(θ₂(t)) - l₂⋅cos(θ₂(t)) ↪
# ↪                      ⎝dt       ⎠                    2                        ↪
# ↪                                                   dt                         ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪             2                  2                                    2⎞       ↪
# ↪  ⎛d        ⎞                  d                          ⎛d        ⎞ ⎟       ↪
# ↪ ⋅⎜──(θ₂(t))⎟  - l₃⋅sin(θ₃(t))⋅───(θ₃(t)) - l₃⋅cos(θ₃(t))⋅⎜──(θ₃(t))⎟ ⎟⋅sin(θ ↪
# ↪  ⎝dt       ⎠                    2                        ⎝dt       ⎠ ⎟       ↪
# ↪                               dt                                     ⎠       ↪
#
# ↪
# ↪
# ↪
# ↪
# ↪
# ↪ ₂(t)) + l₂⋅μ₁(t)⋅cos(θ₂(t)) = 0
# ↪
# ↪

# %%
Eq(diff(diff(theta_2, t), t), simplify(solve(EOM_TLO_2, diff(diff(theta_2, t), t))[0]))
# Out:
#                ⎛                                                               ↪
#                ⎜      d                 d                 d                 d  ↪
#              3⋅⎜4⋅b_B⋅──(θ₁(t)) - 4⋅b_B⋅──(θ₂(t)) - 4⋅b_C⋅──(θ₂(t)) + 4⋅b_C⋅── ↪
#  2             ⎜      dt                dt                dt                dt ↪
# d              ⎝                                                               ↪
# ───(θ₂(t)) = ───────────────────────────────────────────────────────────────── ↪
#   2                                                                            ↪
# dt                                                                             ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ (θ₃(t)) - 2⋅g⋅l₂⋅m₂⋅sin(θ₂(t)) - 4⋅g⋅l₂⋅m₃⋅sin(θ₂(t)) - 4⋅k_B⋅ψ_B + 4⋅k_B⋅θ₁ ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ (t) - 4⋅k_B⋅θ₂(t) + 4⋅k_C⋅ψ_C - 4⋅k_C⋅θ₂(t) + 4⋅k_C⋅θ₃(t) + l₁⋅l₂⋅m₂⋅sin(θ₁( ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                        2                                          2          ↪
# ↪             ⎛d        ⎞                                ⎛d        ⎞           ↪
# ↪ t) - θ₂(t))⋅⎜──(θ₁(t))⎟  + l₁⋅l₂⋅m₂⋅sin(θ₁(t) + θ₂(t))⋅⎜──(θ₁(t))⎟  - l₁⋅l₂⋅ ↪
# ↪             ⎝dt       ⎠                                ⎝dt       ⎠           ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                        2                                        2            ↪
# ↪                       d                                        d             ↪
# ↪ m₂⋅cos(θ₁(t) - θ₂(t))⋅───(θ₁(t)) - l₁⋅l₂⋅m₂⋅cos(θ₁(t) + θ₂(t))⋅───(θ₁(t)) +  ↪
# ↪                         2                                        2           ↪
# ↪                       dt                                       dt            ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                          2                                   ↪
# ↪                               ⎛d        ⎞                                  ⎛ ↪
# ↪ 2⋅l₁⋅l₂⋅m₃⋅sin(θ₁(t) - θ₂(t))⋅⎜──(θ₁(t))⎟  + 2⋅l₁⋅l₂⋅m₃⋅sin(θ₁(t) + θ₂(t))⋅⎜ ↪
# ↪                               ⎝dt       ⎠                                  ⎝ ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                           2 ⎛        2       ↪
# ↪                                                       2⋅l₂ ⋅⎝3⋅m₂⋅cos (θ₂(t) ↪
#
# ↪           2                                  2                               ↪
# ↪ d        ⎞                                  d                                ↪
# ↪ ──(θ₁(t))⎟  - 2⋅l₁⋅l₂⋅m₃⋅cos(θ₁(t) - θ₂(t))⋅───(θ₁(t)) - 2⋅l₁⋅l₂⋅m₃⋅cos(θ₁(t ↪
# ↪ dt       ⎠                                    2                              ↪
# ↪                                             dt                               ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                  2       ⎞                                                   ↪
# ↪ ) - m₂ + 6⋅m₃⋅cos (θ₂(t))⎠                                                   ↪
#
# ↪             2                                          2                     ↪
# ↪            d              2                 ⎛d        ⎞        2             ↪
# ↪ ) + θ₂(t))⋅───(θ₁(t)) + l₂ ⋅m₂⋅sin(2⋅θ₂(t))⋅⎜──(θ₂(t))⎟  + 2⋅l₂ ⋅m₃⋅sin(2⋅θ₂ ↪
# ↪              2                              ⎝dt       ⎠                      ↪
# ↪            dt                                                                ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                 2                                          2                 ↪
# ↪      ⎛d        ⎞                                ⎛d        ⎞                  ↪
# ↪ (t))⋅⎜──(θ₂(t))⎟  + l₂⋅l₃⋅m₂⋅sin(θ₂(t) - θ₃(t))⋅⎜──(θ₃(t))⎟  + l₂⋅l₃⋅m₂⋅sin( ↪
# ↪      ⎝dt       ⎠                                ⎝dt       ⎠                  ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                           2                                2                 ↪
# ↪                ⎛d        ⎞                                d                  ↪
# ↪ θ₂(t) + θ₃(t))⋅⎜──(θ₃(t))⎟  + l₂⋅l₃⋅m₂⋅cos(θ₂(t) - θ₃(t))⋅───(θ₃(t)) - l₂⋅l₃ ↪
# ↪                ⎝dt       ⎠                                  2                ↪
# ↪                                                           dt                 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                         2                                                    ↪
# ↪                        d                                          ⎛d         ↪
# ↪ ⋅m₂⋅cos(θ₂(t) + θ₃(t))⋅───(θ₃(t)) + 2⋅l₂⋅l₃⋅m₃⋅sin(θ₂(t) + θ₃(t))⋅⎜──(θ₃(t)) ↪
# ↪                          2                                        ⎝dt        ↪
# ↪                        dt                                                    ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪  2                                  2                                ⎞
# ↪ ⎞                                  d                                 ⎟
# ↪ ⎟  - 2⋅l₂⋅l₃⋅m₃⋅cos(θ₂(t) + θ₃(t))⋅───(θ₃(t)) - 4⋅l₂⋅μ₁(t)⋅cos(θ₂(t))⎟
# ↪ ⎠                                    2                               ⎟
# ↪                                    dt                                ⎠
# ↪ ──────────────────────────────────────────────────────────────────────
# ↪
# ↪

# %%
EOM_TLO_3 = simplify(EOM_3.subs(y, y_TLO) + mu_1 * l_3 * cos(theta_3))
Eq(EOM_TLO_1, 0)
# Out:
#                                                                                ↪
#                                                                                ↪
#                                                                                ↪
#                                                                                ↪
#     d               d           g⋅l₁⋅m₁⋅sin(θ₁(t))                             ↪
# b_B⋅──(θ₁(t)) - b_B⋅──(θ₂(t)) + ────────────────── + g⋅l₁⋅m₂⋅sin(θ₁(t)) + g⋅l₁ ↪
#     dt              dt                  2                                      ↪
#                                                                                ↪
#
# ↪                                                            2                 ↪
# ↪                                                      2    d                  ↪
# ↪                                                    l₁ ⋅m₁⋅───(θ₁(t))         ↪
# ↪                                                             2                ↪
# ↪                                                           dt             2   ↪
# ↪ ⋅m₃⋅sin(θ₁(t)) - k_B⋅ψ_B + k_B⋅θ₁(t) - k_B⋅θ₂(t) + ───────────────── + l₁ ⋅m ↪
# ↪                                                            3                 ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                                           2  ↪
# ↪                                                                ⎛d        ⎞   ↪
# ↪    2                   2           l₁⋅l₂⋅m₂⋅sin(θ₁(t) - θ₂(t))⋅⎜──(θ₂(t))⎟   ↪
# ↪   d              2    d                                        ⎝dt       ⎠   ↪
# ↪ ₂⋅───(θ₁(t)) + l₁ ⋅m₃⋅───(θ₁(t)) + ────────────────────────────────────────  ↪
# ↪     2                   2                             2                      ↪
# ↪   dt                  dt                                                     ↪
#
# ↪                                2                                             ↪
# ↪                               d                                              ↪
# ↪   l₁⋅l₂⋅m₂⋅cos(θ₁(t) - θ₂(t))⋅───(θ₂(t))                                     ↪
# ↪                                 2                                            ↪
# ↪                               dt                                       ⎛d    ↪
# ↪ + ────────────────────────────────────── + l₁⋅l₂⋅m₃⋅sin(θ₁(t) - θ₂(t))⋅⎜──(θ ↪
# ↪                     2                                                  ⎝dt   ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪       2                                2           l₁⋅l₃⋅m₃⋅sin(θ₁(t) - θ₃(t ↪
# ↪      ⎞                                d                                      ↪
# ↪ ₂(t))⎟  + l₁⋅l₂⋅m₃⋅cos(θ₁(t) - θ₂(t))⋅───(θ₂(t)) + ───────────────────────── ↪
# ↪      ⎠                                  2                             2      ↪
# ↪                                       dt                                     ↪
#
# ↪                                                2                 ⎛           ↪
# ↪               2                               d                  ⎜           ↪
# ↪    ⎛d        ⎞    l₁⋅l₃⋅m₃⋅cos(θ₁(t) - θ₃(t))⋅───(θ₃(t))   l₁⋅m₁⋅⎜- l₁⋅sin(θ ↪
# ↪ ))⋅⎜──(θ₃(t))⎟                                  2                ⎜           ↪
# ↪    ⎝dt       ⎠                                dt                 ⎝           ↪
# ↪ ─────────────── + ────────────────────────────────────── + ───────────────── ↪
# ↪                                     2                                        ↪
# ↪                                                                              ↪
#
# ↪        2                                    2                  2             ↪
# ↪       d                          ⎛d        ⎞                  d              ↪
# ↪ ₁(t))⋅───(θ₁(t)) - l₁⋅cos(θ₁(t))⋅⎜──(θ₁(t))⎟  - l₂⋅sin(θ₂(t))⋅───(θ₂(t)) - l ↪
# ↪         2                        ⎝dt       ⎠                    2            ↪
# ↪       dt                                                      dt             ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                            2 ↪
# ↪                                                                              ↪
#
# ↪                         2                  2                                 ↪
# ↪              ⎛d        ⎞                  d                          ⎛d      ↪
# ↪ ₂⋅cos(θ₂(t))⋅⎜──(θ₂(t))⎟  - l₃⋅sin(θ₃(t))⋅───(θ₃(t)) - l₃⋅cos(θ₃(t))⋅⎜──(θ₃( ↪
# ↪              ⎝dt       ⎠                    2                        ⎝dt     ↪
# ↪                                           dt                                 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪     2⎞                                                                       ↪
# ↪    ⎞ ⎟                                                                       ↪
# ↪ t))⎟ ⎟⋅sin(θ₁(t))                                                            ↪
# ↪    ⎠ ⎟                    ⎛                 2                                ↪
# ↪      ⎠                    ⎜                d                          ⎛d     ↪
# ↪ ───────────────── + l₁⋅m₂⋅⎜- l₁⋅sin(θ₁(t))⋅───(θ₁(t)) - l₁⋅cos(θ₁(t))⋅⎜──(θ₁ ↪
# ↪                           ⎜                  2                        ⎝dt    ↪
# ↪                           ⎝                dt                                ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪      2                  2                                    2               ↪
# ↪     ⎞                  d                          ⎛d        ⎞                ↪
# ↪ (t))⎟  - l₂⋅sin(θ₂(t))⋅───(θ₂(t)) - l₂⋅cos(θ₂(t))⋅⎜──(θ₂(t))⎟  - l₃⋅sin(θ₃(t ↪
# ↪     ⎠                    2                        ⎝dt       ⎠                ↪
# ↪                        dt                                                    ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪     2                                    2⎞                    ⎛             ↪
# ↪    d                          ⎛d        ⎞ ⎟                    ⎜             ↪
# ↪ ))⋅───(θ₃(t)) - l₃⋅cos(θ₃(t))⋅⎜──(θ₃(t))⎟ ⎟⋅sin(θ₁(t)) + l₁⋅m₃⋅⎜- l₁⋅sin(θ₁( ↪
# ↪      2                        ⎝dt       ⎠ ⎟                    ⎜             ↪
# ↪    dt                                     ⎠                    ⎝             ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪      2                                    2                  2               ↪
# ↪     d                          ⎛d        ⎞                  d                ↪
# ↪ t))⋅───(θ₁(t)) - l₁⋅cos(θ₁(t))⋅⎜──(θ₁(t))⎟  - l₂⋅sin(θ₂(t))⋅───(θ₂(t)) - l₂⋅ ↪
# ↪       2                        ⎝dt       ⎠                    2              ↪
# ↪     dt                                                      dt               ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                       2                  2                                   ↪
# ↪            ⎛d        ⎞                  d                          ⎛d        ↪
# ↪ cos(θ₂(t))⋅⎜──(θ₂(t))⎟  - l₃⋅sin(θ₃(t))⋅───(θ₃(t)) - l₃⋅cos(θ₃(t))⋅⎜──(θ₃(t) ↪
# ↪            ⎝dt       ⎠                    2                        ⎝dt       ↪
# ↪                                         dt                                   ↪
#
# ↪
# ↪
# ↪
# ↪   2⎞
# ↪  ⎞ ⎟
# ↪ )⎟ ⎟⋅sin(θ₁(t)) + l₁⋅μ₁(t)⋅cos(θ₁(t)) = 0
# ↪  ⎠ ⎟
# ↪    ⎠

# %%
Eq(diff(diff(theta_3, t), t), simplify(solve(EOM_TLO_3, diff(diff(theta_3, t), t))[0]))
# Out:
#                ⎛                                                               ↪
#                ⎜      d                 d                                      ↪
#              3⋅⎜4⋅b_C⋅──(θ₂(t)) - 4⋅b_C⋅──(θ₃(t)) - 2⋅g⋅l₃⋅m₃⋅sin(θ₃(t)) - 4⋅k ↪
#  2             ⎜      dt                dt                                     ↪
# d              ⎝                                                               ↪
# ───(θ₃(t)) = ───────────────────────────────────────────────────────────────── ↪
#   2                                                                            ↪
# dt                                                                             ↪
#
# ↪                                                                              ↪
# ↪                                                                  ⎛d        ⎞ ↪
# ↪ _C⋅ψ_C + 4⋅k_C⋅θ₂(t) - 4⋅k_C⋅θ₃(t) + l₁⋅l₃⋅m₃⋅sin(θ₁(t) - θ₃(t))⋅⎜──(θ₁(t))⎟ ↪
# ↪                                                                  ⎝dt       ⎠ ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ 2                                          2                                 ↪
# ↪                                 ⎛d        ⎞                                d ↪
# ↪   + l₁⋅l₃⋅m₃⋅sin(θ₁(t) + θ₃(t))⋅⎜──(θ₁(t))⎟  - l₁⋅l₃⋅m₃⋅cos(θ₁(t) - θ₃(t))⋅─ ↪
# ↪                                 ⎝dt       ⎠                                  ↪
# ↪                                                                            d ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ 2                                        2                                   ↪
# ↪                                         d                                    ↪
# ↪ ──(θ₁(t)) - l₁⋅l₃⋅m₃⋅cos(θ₁(t) + θ₃(t))⋅───(θ₁(t)) + l₂⋅l₃⋅m₃⋅sin(θ₂(t) - θ₃ ↪
# ↪  2                                        2                                  ↪
# ↪ t                                       dt                                   ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                    2                                                         ↪
# ↪                  l₃ ⋅m₃⋅(3⋅cos(2⋅θ₃(t)) + 1)                                 ↪
#
# ↪                 2                                          2                 ↪
# ↪      ⎛d        ⎞                                ⎛d        ⎞                  ↪
# ↪ (t))⋅⎜──(θ₂(t))⎟  + l₂⋅l₃⋅m₃⋅sin(θ₂(t) + θ₃(t))⋅⎜──(θ₂(t))⎟  - l₂⋅l₃⋅m₃⋅cos( ↪
# ↪      ⎝dt       ⎠                                ⎝dt       ⎠                  ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                 2                                        2                   ↪
# ↪                d                                        d              2     ↪
# ↪ θ₂(t) - θ₃(t))⋅───(θ₂(t)) - l₂⋅l₃⋅m₃⋅cos(θ₂(t) + θ₃(t))⋅───(θ₂(t)) + l₃ ⋅m₃⋅ ↪
# ↪                  2                                        2                  ↪
# ↪                dt                                       dt                   ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                         2                        ⎞
# ↪              ⎛d        ⎞                         ⎟
# ↪ sin(2⋅θ₃(t))⋅⎜──(θ₃(t))⎟  - 4⋅l₃⋅μ₁(t)⋅cos(θ₃(t))⎟
# ↪              ⎝dt       ⎠                         ⎟
# ↪                                                  ⎠
# ↪ ──────────────────────────────────────────────────
# ↪
# ↪

# %%
Eq(const_TLO_u_D, 0)
# Out:
#               d                         d                         d            ↪
# l₁⋅cos(θ₁(t))⋅──(θ₁(t)) + l₂⋅cos(θ₂(t))⋅──(θ₂(t)) + l₃⋅cos(θ₃(t))⋅──(θ₃(t)) +  ↪
#               dt                        dt                        dt           ↪
#
# ↪
# ↪ v = 0
# ↪
