# %% [markdown]
# PYTHON PACKAGE IMPORIUM

# %%
from sympy import *
import numpy as np
import pandas as pd
init_printing()
import matplotlib.pyplot as plt
import scipy as sp
from scipy.integrate import odeint
from scipy.integrate import solve_ivp
from matplotlib import animation
from matplotlib.animation import PillowWriter
from IPython.display import HTML

# %% [markdown]
# Importing the real data and creating gradients

# %%
### Imports the data from the videos these are on google sheets

## Links for information
#Swing
# https://docs.google.com/spreadsheets/d/1_7QRQoNtSvBf8SGO_7QMUrW1H4530k6mT_Gq0PwPk5g/edit?usp=sharing


# Heel Strike
# https://docs.google.com/spreadsheets/d/1X28PZPv4YCRk0JKEC6BHRNPEU3d-jScm01EGPgLpGG0/edit?usp=sharing

# Foot plant
# https://docs.google.com/spreadsheets/d/1omfkgiZVONb8tLBRJC7OKSXqIFZG1T_8hXWkyYviHwc/edit?usp=sharing


# Toe Push off
# https://docs.google.com/spreadsheets/d/1WJXOAKJVESN-oYRf8KPlqSbBiQPxoxrlgLnAdw2M_7k/edit?usp=sharing


## Pandas needed code

## Swing

Sheet_ID_Swing = '1_7QRQoNtSvBf8SGO_7QMUrW1H4530k6mT_Gq0PwPk5g'
df_Swing = pd.read_csv(f"https://docs.google.com/spreadsheets/d/{Sheet_ID_Swing}/export?format=csv")

## Heel Strike

Sheet_ID_HeelStrike = '1X28PZPv4YCRk0JKEC6BHRNPEU3d-jScm01EGPgLpGG0'
df_HeelStrike = pd.read_csv(f"https://docs.google.com/spreadsheets/d/{Sheet_ID_HeelStrike}/export?format=csv")

## Foot plant

Sheet_ID_FootPlant = '1omfkgiZVONb8tLBRJC7OKSXqIFZG1T_8hXWkyYviHwc'
df_FootPlant = pd.read_csv(f"https://docs.google.com/spreadsheets/d/{Sheet_ID_FootPlant}/export?format=csv")

## Toe Push off

Sheet_ID_ToePushOff = '1WJXOAKJVESN-oYRf8KPlqSbBiQPxoxrlgLnAdw2M_7k'
df_ToePushOff = pd.read_csv(f"https://docs.google.com/spreadsheets/d/{Sheet_ID_ToePushOff}/export?format=csv")

# %%
## Adjusting time to be in seconds
df_Swing.iloc[:,0] = df_Swing.iloc[:,0]/1000
df_HeelStrike.iloc[:,0] = df_HeelStrike.iloc[:,0]/1000
df_FootPlant.iloc[:,0] = df_FootPlant.iloc[:,0]/1000
df_ToePushOff.iloc[:,0] = df_ToePushOff.iloc[:,0]/1000
# Out:
# C:\Users\natha\AppData\Local\Temp\ipykernel_33208\1619488405.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0     0.000
# 1     0.035
# 2     0.068
# 3     0.102
# 4     0.136
# 5     0.170
# 6     0.204
# 7     0.238
# 8     0.272
# 9     0.306
# 10    0.340
# 11    0.374
# 12    0.407
# 13    0.441
# 14    0.484
# 15    0.517
# 16    0.550
# 17    0.617
# 18    0.650
# 19    0.684
# 20    0.709
# Name: Time (ms), dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_Swing.iloc[:,0] = df_Swing.iloc[:,0]/1000
# C:\Users\natha\AppData\Local\Temp\ipykernel_33208\1619488405.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0     0.000
# 1     0.033
# 2     0.067
# 3     0.091
# 4     0.125
# 5     0.159
# 6     0.202
# 7     0.235
# 8     0.268
# 9     0.302
# 10    0.335
# 11    0.369
# Name: Time (ms), dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_HeelStrike.iloc[:,0] = df_HeelStrike.iloc[:,0]/1000
# C:\Users\natha\AppData\Local\Temp\ipykernel_33208\1619488405.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0     0.000
# 1     0.034
# 2     0.068
# 3     0.111
# 4     0.144
# 5     0.177
# 6     0.211
# 7     0.244
# 8     0.277
# 9     0.310
# 10    0.344
# 11    0.377
# 12    0.410
# 13    0.435
# 14    0.469
# 15    0.503
# 16    0.537
# 17    0.571
# 18    0.613
# 19    0.647
# 20    0.680
# 21    0.705
# 22    0.739
# 23    0.773
# 24    0.807
# 25    0.841
# Name: Time (ms), dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_FootPlant.iloc[:,0] = df_FootPlant.iloc[:,0]/1000
# C:\Users\natha\AppData\Local\Temp\ipykernel_33208\1619488405.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0    0.000
# 1    0.034
# 2    0.068
# 3    0.102
# 4    0.136
# 5    0.170
# 6    0.204
# 7    0.246
# Name: Time (ms), dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_ToePushOff.iloc[:,0] = df_ToePushOff.iloc[:,0]/1000

# %% [markdown]
# Where the functions will live

# %%
def gradienter(func):
    func.iloc[:,2] = np.gradient(func.iloc[:,1] , func.iloc[:,0])# velocity
    func.iloc[:,3] = np.gradient(func.iloc[:,2] , func.iloc[:,0]) # Acceleration

    func.iloc[:,5] = np.gradient(func.iloc[:,4] , func.iloc[:,0])  # omega
    func.iloc[:,6] = np.gradient(func.iloc[:,5] , func.iloc[:,0])  # alpha

# %%
### Gradients all the data

gradienter(df_Swing)
gradienter(df_HeelStrike)
gradienter(df_FootPlant)
gradienter(df_ToePushOff)
# Out:
# C:\Users\natha\AppData\Local\Temp\ipykernel_33208\593550914.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-1.67714286 -1.52045837 -0.71688882  0.97941176  2.94264706  4.41911765
#   5.06323529  4.96911765  4.35882353  3.48382353  2.57941176  1.7219105
#   0.76146274 -0.30440244 -2.04672583 -3.60909091 -3.62755495 -3.00831253
#  -2.71316679 -1.67305284 -1.424     ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   func.iloc[:,2] = np.gradient(func.iloc[:,1] , func.iloc[:,0])# velocity
# C:\Users\natha\AppData\Local\Temp\ipykernel_33208\593550914.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[  4.47669977  14.70590918  36.93029147  53.81670407  50.58391003
#   31.18512111   8.08823529 -10.35899654 -21.84256055 -26.16782007
#  -25.91048571 -27.19153548 -30.20997672 -35.398143   -44.38080198
#  -23.95195646   2.67512397   9.04235294  19.60614792  18.70341576
#    9.96211366]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   func.iloc[:,3] = np.gradient(func.iloc[:,2] , func.iloc[:,0]) # Acceleration
# C:\Users\natha\AppData\Local\Temp\ipykernel_33208\593550914.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 74.963       78.12437032  79.9154816   76.72711765  71.46827941
#   64.95680882  59.50044118  55.88617647  53.36897059  50.52294118
#   45.76588235  38.28428353  27.24319046  14.04404214   3.49738975
#    3.53181818   6.05104387  11.36840751   5.97810812 -18.50158524
#  -30.78      ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   func.iloc[:,5] = np.gradient(func.iloc[:,4] , func.iloc[:,0])  # omega
# C:\Users\natha\AppData\Local\Temp\ipykernel_33208\593550914.py:6: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[  90.32486631   71.77035396  -18.64479349 -124.22356163 -173.09277682
#  -175.99762111 -133.39165225  -90.16868512  -78.87110727 -111.81012111
#  -179.98025952 -278.16751405 -360.99417493 -325.0942084  -105.90896371
#    38.69172914   77.33791552  -83.24941176 -437.51259965 -588.10878987
#  -491.13659023]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   func.iloc[:,6] = np.gradient(func.iloc[:,5] , func.iloc[:,0])  # alpha
# C:\Users\natha\AppData\Local\Temp\ipykernel_33208\593550914.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.76060606 -1.16100114 -2.37065585 -1.96416498  0.86029412  2.5181072
#   2.2628417   0.91363636  0.0930029   0.90186767  1.8724559   2.2       ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   func.iloc[:,2] = np.gradient(func.iloc[:,1] , func.iloc[:,0])# velocity
# C:\Users\natha\AppData\Local\Temp\ipykernel_33208\593550914.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-12.13318435 -23.68067004  -4.79330759  44.30341207  65.91576731
#   24.60789764 -25.70995878 -32.87634541  -0.90188832  26.64290488
#   19.67030519   9.63364993]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   func.iloc[:,3] = np.gradient(func.iloc[:,2] , func.iloc[:,0]) # Acceleration
# C:\Users\natha\AppData\Local\Temp\ipykernel_33208\593550914.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 19.12121212  10.86655892 -15.81998817 -32.28895368 -41.02058824
#  -40.8186162  -42.6811945  -49.22227273 -51.05579496 -51.89341594
#  -50.5527004  -48.74058824]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   func.iloc[:,5] = np.gradient(func.iloc[:,4] , func.iloc[:,0])  # omega
# C:\Users\natha\AppData\Local\Temp\ipykernel_33208\593550914.py:6: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-250.1410062  -513.52899778 -727.04477811 -508.52657283 -125.43621344
#   -15.80910534 -130.95583815 -126.88788564  -40.32938183    8.48295834
#    46.86803035   53.29741666]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   func.iloc[:,6] = np.gradient(func.iloc[:,5] , func.iloc[:,0])  # alpha
# C:\Users\natha\AppData\Local\Temp\ipykernel_33208\593550914.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 0.22647059  0.96911765  1.78563967  1.89776993  1.46060606  0.86988986
#   0.94831591  1.42424242  1.79848485  1.82937319  1.60793492  1.31818182
#   1.2763302   1.24715055  1.2         1.43235294  1.57941176  1.34548135
#   0.74083739  0.05830473 -0.99754232 -1.49670189 -1.69411765 -1.93823529
#  -2.06617647 -2.10294118]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   func.iloc[:,2] = np.gradient(func.iloc[:,1] , func.iloc[:,0])# velocity
# C:\Users\natha\AppData\Local\Temp\ipykernel_33208\593550914.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 21.84256055  22.92895706  14.56261478  -6.36295146 -15.57394048
#   -7.94772079   8.45474531  12.8813476    6.1383449   -2.7328511
#   -7.66356532  -5.02431403  -1.21073984  -1.26023466   2.7235646
#    5.57958478  -1.27752339 -10.24271775 -17.53424023 -26.12388929
#  -25.15128913 -13.96636717  -6.49313823  -5.47145329  -2.42214533
#   -1.08131488]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   func.iloc[:,3] = np.gradient(func.iloc[:,2] , func.iloc[:,0]) # Acceleration
# C:\Users\natha\AppData\Local\Temp\ipykernel_33208\593550914.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-37.53823529 -39.81617647 -38.43650363 -41.12441777 -48.55257576
#  -50.39572339 -50.94009245 -50.63621212 -48.36683333 -43.93579098
#  -38.09109717 -31.57813636 -28.97402564 -26.45213675 -23.14092647
#  -26.04408824 -29.20316176 -28.97232183 -29.73279165 -31.36302861
#  -34.93615423 -33.98964945 -28.23808824 -27.8475     -26.94235294
#  -26.47411765]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   func.iloc[:,5] = np.gradient(func.iloc[:,4] , func.iloc[:,0])  # omega
# C:\Users\natha\AppData\Local\Temp\ipykernel_33208\593550914.py:6: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ -66.9982699   -13.20982852   -4.94087148 -154.49911552 -140.47432755
#   -36.2292358    -3.21297587   38.98877453  101.52153247  152.80757329
#   184.82260156  138.13744745   91.40869812   99.39800568    6.00071345
#   -89.15051903  -43.0622588    -4.34820016  -34.59790204  -78.56255181
#   -25.1297765    93.49721408   90.32572723   19.0549308    20.19679931
#    13.7716263 ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   func.iloc[:,6] = np.gradient(func.iloc[:,5] , func.iloc[:,0])  # alpha
# C:\Users\natha\AppData\Local\Temp\ipykernel_33208\593550914.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-3.24117647 -2.25       -0.42794118  0.89117647  0.80735294 -1.32647059
#  -2.63040321 -2.31190476]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   func.iloc[:,2] = np.gradient(func.iloc[:,1] , func.iloc[:,0])# velocity
# C:\Users\natha\AppData\Local\Temp\ipykernel_33208\593550914.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 29.15224913  41.37110727  46.19377163  18.16608997 -32.61245675
#  -50.55523757 -17.80142398   7.58329648]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   func.iloc[:,3] = np.gradient(func.iloc[:,2] , func.iloc[:,0]) # Acceleration
# C:\Users\natha\AppData\Local\Temp\ipykernel_33208\593550914.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-15.95911765 -16.66676471  -7.70176471  15.65161765  50.04147059
#   76.0375      79.79395061  77.90338095]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   func.iloc[:,5] = np.gradient(func.iloc[:,4] , func.iloc[:,0])  # omega
# C:\Users\natha\AppData\Local\Temp\ipykernel_33208\593550914.py:6: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-20.81314879 121.4316609  475.27032872 849.16522491 888.02768166
#  437.53647094  40.91921304 -45.01356332]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   func.iloc[:,6] = np.gradient(func.iloc[:,5] , func.iloc[:,0])  # alpha

# %%
## This is needed for functions
count = symbols('count')

# %% [markdown]
# DEFINE TIME AND GRAVITY

# %%
t = symbols('t')
g = symbols('g')

# %% [markdown]
# DEFINE THE BASE BASE VARIABLES

# %%
# limb lengths
l_1, l_2, l_3, l_4 = symbols('l_1, l_2, l_3, l_4')

# limb masses
m_1, m_2, m_3, m_A = symbols('m_1, m_2, m_3, m_A')

# joint stiffnesses
k_B, k_C = symbols('k_B, k_C')

# joint damping
b_B, b_C = symbols('b_B, b_C')

# joint neutral angles
psi_B, psi_C = symbols('psi_B, psi_C')

# foot angle
phi_D = symbols('phi_E')

# Walking speed
vel_W = symbols('v')

# Swing phase hip height
y_A_SW = Function('y_ASW')(t)

# Gravity
g = symbols('g')

# %% [markdown]
# DEFINE THE GENERALIZED COORDINATES

# %%
# limb orientations
theta_1 = Function('theta_1')(t)
theta_2 = Function('theta_2')(t)
theta_3 = Function('theta_3')(t)

# hip height
y = Function('y')(t)

# %% [markdown]
# CALCULATE POSITIONS AND VELOCITIES

# %%
# rates of change
omega_1 = diff(theta_1,t)
omega_2 = diff(theta_2,t)
omega_3 = diff(theta_3,t) 
v = diff(y,t)

# heel angle
theta_4 = theta_3 - phi_D
omega_4 = diff(theta_4, t)

# joint positions
x_A = 0
y_A = y
x_B = x_A + l_1 * sin(theta_1)
y_B = y_A - l_1 * cos(theta_1)
x_C = x_B + l_2 * sin(theta_2)
y_C = y_B - l_2 * cos(theta_2)
x_D = x_C + l_4 * sin(theta_4)
y_D = y_C - l_4 * cos(theta_4)
x_E = x_C + l_4 * sin(theta_4)
y_E = y_C - l_4 * cos(theta_4)

# joint velocities
u_A = diff(x_A, t)
v_A = diff(y_A, t)
u_B = diff(x_B, t)
v_B = diff(y_B, t)
u_C = diff(x_C, t)
v_C = diff(y_C, t)
u_D = diff(x_D, t)
v_D = diff(y_D, t)
u_E = diff(x_E, t)
v_E = diff(y_E, t)

# Centers of masses
x_1 = x_A + l_1 * sin(theta_1) / 2
y_1 = y_A - l_1 * cos(theta_1) / 2
x_2 = x_B + l_2 * sin(theta_2) / 2
y_2 = y_B - l_2 * cos(theta_2) / 2
x_3 = x_C + l_3 * sin(theta_3) / 2
y_3 = y_C - l_3 * cos(theta_3) / 2

# COM velocities
u_1 = diff(x_1, t)
v_1 = diff(y_1, t)
u_2 = diff(x_2, t)
v_2 = diff(y_2, t)
u_3 = diff(x_3, t)
v_3 = diff(y_3, t)

# %%
#Alpha 
alpha_1 = diff(omega_1,t)
alpha_2 = diff(omega_2,t)
alpha_3 = diff(omega_3,t)
a = diff(v_A,t)

# %%
# Moments of inertia
I_1 = m_1 * l_1**2 / 12
I_2 = m_2 * l_2**2 / 12
I_3 = m_3 * l_3**2 / 12  ## FIX THIS

# %%
# Non-Holonomic lagrangian Multiplier

## HS
mu_1_HS = symbols('mu_1_HS')

# %% [markdown]
# Calculate Lagrangian

# %%
### LAGRANGIAN COMPONENTS complex
# Kinetic Energy
T = simplify((m_1 * (u_1**2 + v_1**2) / 2) + (m_2 * (u_2**2 + v_2**2) / 2) + m_3 * (u_3**2 + v_3**2) / 2 + (I_1 * omega_1**2 / 2) + (I_2 * omega_2**2 / 2)  + (I_3 * omega_3**2 / 2))

# Potential Energy
V = simplify(k_B * (theta_1 - theta_2 - psi_B)**2 / 2 + k_C * (theta_2 - theta_3 - psi_C)**2 / 2)

# Content
D =simplify( b_B * (omega_1 - omega_2)**2 / 2 + b_C * (omega_2 - omega_3)**2 / 2)

# %% [markdown]
# CONSTRAINT EQUATIONS

# %%
## Constraint equations ###

''' Notes: 
    - This is a section to lay out the constraints/define the "regiemes". I am wondering if for our analysis we should pull set this in a 
       for loop? By that I mean should it be have a matrix where time is the top row and we ha
       e a row for each theta. At every time interval 
       we have a measured theta. The below constraints then are only active over their "regieme" and apply to the analysis in their specified
       time domain?
    '''

# Swing

'''Notes:
      - This is the stage where the one leg is swinging while the other leg is standing up going through the cycle.
  
  '''

const_SW_y_A = y_A - y_A_SW


# Heel_Strike
'''Notes:
            - This is where heel strike contacts the gorund and jhas the following contraints
                - y_E = 0 
                - u_3 = 0
                - v_3 = 0 
                - y_D = ED*sin(theta3) This is inherent to the system will not be set

                Side: Note, should this be a for loop with a matrix? like for t = .1->.25 then have the HS constraints?
                   '''

const_HS_y_E = y_E
const_HS_u_E = u_E + vel_W


# Foot_Planted

'''Notes:
            - This is where the foot is "pulling" across the ground to push the body forward. As we have restricted Y to the 0,0
              position, the foot will be moving around it.
                - y_E = 0 due to the foot being on the ground
                - y_D = 0 due to the foot being on the gorund
                - v_3 = due to the foot not traveling upward 
                   '''

const_FP_y_E = y_E
const_FP_y_D = y_D
const_FP_u_E = u_E + vel_W
const_FP_u_D = u_D + vel_W

# Toe_Lift_Off
'''Notes:
            - This is where the toe is about to kick off of the ground. 
                - y_D = 0 due to the foot being on the gorund

'''

const_TLO_y_D = y_D
const_TLO_u_D = u_D + vel_W

# %% [markdown]
# SOLVING AND LINEARIZING THE CONSTRAINTS PER PHASE

# %%
### Swing
SOLVED_Y_const_SW_y_A = solve(const_SW_y_A, y)[0]

# %%
### HEEL STRIKE
Y_HS = solve(const_HS_y_E,y)[0]
omega_3HS = solve(const_HS_u_E, omega_3)[0]

# %%
### Foot plant constraints in terms of singel values

Y_FP = solve(const_FP_y_E,y)[0] # this get the foot position of E in terms of y
theta_2FP = simplify(solve(const_FP_y_D, theta_2)[0])
theta_2FP = theta_2FP.subs(y, Y_FP)
theta_2FP 
#omega_2_FP = simplify(solve(const_FP_u_E.subs(theta_2,theta_2FP),omega_2))# This omega 2 to define the velocity of E
# Out:
# -acos(cos(θ₂(t))) + 2⋅π

# %%
### TOE_LIFT_OFF

Y_T_L_F_D = (solve(const_TLO_y_D,y))[0]
U_D_T_L_D = (solve(const_TLO_u_D.subs(y,Y_T_L_F_D),v)) ###UUHUHUUHHUHUHU

#const_TLO_y_D = y_D
#const_TLO_u_D = u_D + v

# %% [markdown]
# Equations of Motion for generalized coordinates (no constraints or efforts)
# THIS IS THE WAY WE WERE DOING IT BEFORE

# %%
# y
ddydt = simplify(solve( (diff(diff(T, v_A), t) - diff(T, y) + diff(D, v_A) + diff(V, y)) , a, simplify=False, rational=False)[0])
ddydt
# Out:
#                     2                                                          ↪
#                    d                                        2                  ↪
#   l₁⋅m₁⋅sin(θ₁(t))⋅───(θ₁(t))                    ⎛d        ⎞                   ↪
#                      2          l₁⋅m₁⋅cos(θ₁(t))⋅⎜──(θ₁(t))⎟                   ↪
#                    dt                            ⎝dt       ⎠                   ↪
# - ─────────────────────────── - ───────────────────────────── - l₁⋅m₂⋅sin(θ₁(t ↪
#                2                              2                                ↪
#                                                                                ↪
# ────────────────────────────────────────────────────────────────────────────── ↪
#                                                                                ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪     2                                       2                     2          ↪
# ↪    d                             ⎛d        ⎞                     d           ↪
# ↪ ))⋅───(θ₁(t)) - l₁⋅m₂⋅cos(θ₁(t))⋅⎜──(θ₁(t))⎟  - l₁⋅m₃⋅sin(θ₁(t))⋅───(θ₁(t))  ↪
# ↪      2                           ⎝dt       ⎠                       2         ↪
# ↪    dt                                                            dt          ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
#
# ↪                                                     2                        ↪
# ↪                                                    d                         ↪
# ↪                                   l₂⋅m₂⋅sin(θ₂(t))⋅───(θ₂(t))                ↪
# ↪                               2                      2          l₂⋅m₂⋅cos(θ₂ ↪
# ↪                    ⎛d        ⎞                     dt                        ↪
# ↪ - l₁⋅m₃⋅cos(θ₁(t))⋅⎜──(θ₁(t))⎟  - ─────────────────────────── - ──────────── ↪
# ↪                    ⎝dt       ⎠                 2                             ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                          m₁ + m₂ + m₃                                        ↪
#
# ↪                                                                              ↪
# ↪                 2                                                            ↪
# ↪      ⎛d        ⎞                                                             ↪
# ↪ (t))⋅⎜──(θ₂(t))⎟                      2                                      ↪
# ↪      ⎝dt       ⎠                     d                             ⎛d        ↪
# ↪ ───────────────── - l₂⋅m₃⋅sin(θ₂(t))⋅───(θ₂(t)) - l₂⋅m₃⋅cos(θ₂(t))⋅⎜──(θ₂(t) ↪
# ↪   2                                    2                           ⎝dt       ↪
# ↪                                      dt                                      ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
#
# ↪                         2
# ↪                        d                                        2
# ↪       l₃⋅m₃⋅sin(θ₃(t))⋅───(θ₃(t))                    ⎛d        ⎞
# ↪   2                      2          l₃⋅m₃⋅cos(θ₃(t))⋅⎜──(θ₃(t))⎟
# ↪  ⎞                     dt                            ⎝dt       ⎠
# ↪ )⎟  - ─────────────────────────── - ─────────────────────────────
# ↪  ⎠                 2                              2
# ↪
# ↪ ─────────────────────────────────────────────────────────────────
# ↪

# %%
# theta_1
ddtheta_1_dt =  simplify(solve((diff(diff(T, omega_1), t) - diff(T, theta_1) + diff(D, omega_1) + diff(V, theta_1)), alpha_1, simplify=False, rational=False )[0])
ddtheta_1_dt
# Out:
#   ⎛                                                                            ↪
#   ⎜        d                 d                                                 ↪
# 3⋅⎜- 2⋅b_B⋅──(θ₁(t)) + 2⋅b_B⋅──(θ₂(t)) + 2⋅k_B⋅ψ_B - 2⋅k_B⋅θ₁(t) + 2⋅k_B⋅θ₂(t) ↪
#   ⎜        dt                dt                                                ↪
#   ⎝                                                                            ↪
# ────────────────────────────────────────────────────────────────────────────── ↪
#                                                                                ↪
#                                                                                ↪
#
# ↪                                           2                                2 ↪
# ↪                                ⎛d        ⎞                                d  ↪
# ↪  - l₁⋅l₂⋅m₂⋅sin(θ₁(t) - θ₂(t))⋅⎜──(θ₂(t))⎟  - l₁⋅l₂⋅m₂⋅cos(θ₁(t) - θ₂(t))⋅── ↪
# ↪                                ⎝dt       ⎠                                   ↪
# ↪                                                                           dt ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                     2                        ↪
# ↪                                          ⎛d        ⎞                         ↪
# ↪ ─(θ₂(t)) - 2⋅l₁⋅l₂⋅m₃⋅sin(θ₁(t) - θ₂(t))⋅⎜──(θ₂(t))⎟  - 2⋅l₁⋅l₂⋅m₃⋅cos(θ₁(t) ↪
# ↪ 2                                        ⎝dt       ⎠                         ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                    2                         ↪
# ↪                                                2⋅l₁ ⋅(m₁ + 3⋅m₂ + 3⋅m₃)      ↪
#
# ↪            2                                                  2              ↪
# ↪           d                                        ⎛d        ⎞               ↪
# ↪  - θ₂(t))⋅───(θ₂(t)) - l₁⋅l₃⋅m₃⋅sin(θ₁(t) - θ₃(t))⋅⎜──(θ₃(t))⎟  - l₁⋅l₃⋅m₃⋅c ↪
# ↪             2                                      ⎝dt       ⎠               ↪
# ↪           dt                                                                 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                    2                             2                           ↪
# ↪                   d                             d                            ↪
# ↪ os(θ₁(t) - θ₃(t))⋅───(θ₃(t)) - l₁⋅m₁⋅sin(θ₁(t))⋅───(y(t)) - 2⋅l₁⋅m₂⋅sin(θ₁(t ↪
# ↪                     2                             2                          ↪
# ↪                   dt                            dt                           ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪     2                              2       ⎞
# ↪    d                              d        ⎟
# ↪ ))⋅───(y(t)) - 2⋅l₁⋅m₃⋅sin(θ₁(t))⋅───(y(t))⎟
# ↪      2                              2      ⎟
# ↪    dt                             dt       ⎠
# ↪ ────────────────────────────────────────────
# ↪
# ↪

# %%
# theta_2
ddtheta_2_dt =  simplify(solve((diff(diff(T, omega_2), t) - diff(T, theta_2) + diff(D, omega_2) + diff(V, theta_2)), alpha_2, simplify=False, rational=False )[0])
ddtheta_2_dt
# Out:
#   ⎛                                                                            ↪
#   ⎜      d                 d                 d                 d               ↪
# 3⋅⎜2⋅b_B⋅──(θ₁(t)) - 2⋅b_B⋅──(θ₂(t)) - 2⋅b_C⋅──(θ₂(t)) + 2⋅b_C⋅──(θ₃(t)) - 2⋅k ↪
#   ⎜      dt                dt                dt                dt              ↪
#   ⎝                                                                            ↪
# ────────────────────────────────────────────────────────────────────────────── ↪
#                                                                                ↪
#                                                                                ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ _B⋅ψ_B + 2⋅k_B⋅θ₁(t) - 2⋅k_B⋅θ₂(t) + 2⋅k_C⋅ψ_C - 2⋅k_C⋅θ₂(t) + 2⋅k_C⋅θ₃(t) + ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                         2                                2   ↪
# ↪                              ⎛d        ⎞                                d    ↪
# ↪  l₁⋅l₂⋅m₂⋅sin(θ₁(t) - θ₂(t))⋅⎜──(θ₁(t))⎟  - l₁⋅l₂⋅m₂⋅cos(θ₁(t) - θ₂(t))⋅───( ↪
# ↪                              ⎝dt       ⎠                                  2  ↪
# ↪                                                                         dt   ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                         2⋅l₂ ↪
#
# ↪                                                   2                          ↪
# ↪                                        ⎛d        ⎞                           ↪
# ↪ θ₁(t)) + 2⋅l₁⋅l₂⋅m₃⋅sin(θ₁(t) - θ₂(t))⋅⎜──(θ₁(t))⎟  - 2⋅l₁⋅l₂⋅m₃⋅cos(θ₁(t) - ↪
# ↪                                        ⎝dt       ⎠                           ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪ 2                                                                            ↪
# ↪  ⋅(m₂ + 3⋅m₃)                                                                ↪
#
# ↪          2                                                  2                ↪
# ↪         d                                        ⎛d        ⎞                 ↪
# ↪  θ₂(t))⋅───(θ₁(t)) - l₂⋅l₃⋅m₃⋅sin(θ₂(t) - θ₃(t))⋅⎜──(θ₃(t))⎟  - l₂⋅l₃⋅m₃⋅cos ↪
# ↪           2                                      ⎝dt       ⎠                 ↪
# ↪         dt                                                                   ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                  2                             2                             ↪
# ↪                 d                             d                              ↪
# ↪ (θ₂(t) - θ₃(t))⋅───(θ₃(t)) - l₂⋅m₂⋅sin(θ₂(t))⋅───(y(t)) - 2⋅l₂⋅m₃⋅sin(θ₂(t)) ↪
# ↪                   2                             2                            ↪
# ↪                 dt                            dt                             ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪   2       ⎞
# ↪  d        ⎟
# ↪ ⋅───(y(t))⎟
# ↪    2      ⎟
# ↪  dt       ⎠
# ↪ ───────────
# ↪
# ↪

# %%
# theta_3
ddtheta_3_dt =  simplify(solve((diff(diff(T, omega_3), t) - diff(T, theta_3) + diff(D, omega_3) + diff(V, theta_3)), alpha_3, simplify=False, rational=False )[0])
ddtheta_3_dt
# Out:
#   ⎛                                                                            ↪
#   ⎜      d                 d                                                   ↪
# 3⋅⎜2⋅b_C⋅──(θ₂(t)) - 2⋅b_C⋅──(θ₃(t)) - 2⋅k_C⋅ψ_C + 2⋅k_C⋅θ₂(t) - 2⋅k_C⋅θ₃(t) + ↪
#   ⎜      dt                dt                                                  ↪
#   ⎝                                                                            ↪
# ────────────────────────────────────────────────────────────────────────────── ↪
#                                                                                ↪
#                                                                                ↪
#
# ↪                                         2                                2   ↪
# ↪                              ⎛d        ⎞                                d    ↪
# ↪  l₁⋅l₃⋅m₃⋅sin(θ₁(t) - θ₃(t))⋅⎜──(θ₁(t))⎟  - l₁⋅l₃⋅m₃⋅cos(θ₁(t) - θ₃(t))⋅───( ↪
# ↪                              ⎝dt       ⎠                                  2  ↪
# ↪                                                                         dt   ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                            2                 ↪
# ↪                                                        2⋅l₃ ⋅m₃              ↪
#
# ↪                                                 2                            ↪
# ↪                                      ⎛d        ⎞                             ↪
# ↪ θ₁(t)) + l₂⋅l₃⋅m₃⋅sin(θ₂(t) - θ₃(t))⋅⎜──(θ₂(t))⎟  - l₂⋅l₃⋅m₃⋅cos(θ₂(t) - θ₃( ↪
# ↪                                      ⎝dt       ⎠                             ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪      2                             2       ⎞
# ↪     d                             d        ⎟
# ↪ t))⋅───(θ₂(t)) - l₃⋅m₃⋅sin(θ₃(t))⋅───(y(t))⎟
# ↪       2                             2      ⎟
# ↪     dt                            dt       ⎠
# ↪ ────────────────────────────────────────────
# ↪
# ↪

# %% [markdown]
# CREATION OF THE LEGRANGE EQUATIONS OF MOVEMENT AND THEY ARE "LAGRANGED" PER THE GENERALIZED EQUATIONS

# %%
### Creates the general equations of lagrange
LE_Y = simplify((diff(diff(T, v_A), t) - diff(T, y) + diff(D, v_A) + diff(V, y)))
LE_theta_1 = simplify((diff(diff(T, omega_1), t) - diff(T, theta_1) + diff(D, omega_1) + diff(V, theta_1)))
LE_theta_2 = simplify((diff(diff(T, omega_2), t) - diff(T, theta_2) + diff(D, omega_2) + diff(V, theta_2)))
LE_theta_3 = simplify((diff(diff(T, omega_3), t) - diff(T, theta_3) + diff(D, omega_3) + diff(V, theta_3)))

# %% [markdown]
# ADDING THE APPLIED EFFORTS

# %%
## Creating the applied efforts EQUATIONS PER PARTS

dw_A = -g * m_A * diff(y_A, t)
dw_1 = -g * m_1 * diff(y_1, t)
dw_2 = -g * m_2 * diff(y_2, t)
dw_3 = -g * m_3 * diff(y_3, t)
dw = simplify(dw_A + dw_1 + dw_2 + dw_3)

# %%
### PULLS OUT THE APPLIED EFFORTS SO THAT THEY CAN BE APPLIED TO THE CORRECT EQUATIONS OF MOTION

e_y = dw.subs({theta_1: 0,theta_2: 0, theta_3: 0, y: 1, omega_2: 0, omega_3: 0, v: 1, omega_1: 0})
e_thet1 = dw.subs({theta_2: 0, theta_3: 0, y: 0, omega_2: 0, omega_3: 0, v: 0, omega_1: 1})
e_thet2 = dw.subs({theta_1: 0, theta_3: 0, y: 0, omega_2: 1, omega_3: 0, v: 0, omega_1: 0})
e_thet3 = dw.subs({theta_1: 0,theta_2: 0,  y: 0, omega_2: 0, omega_3: 1, v: 0, omega_1: 0})

# %%
### Applies the efforts to the respective equation of motion

LE_Y_W = LE_Y - e_y
LE_theta_1_W = LE_theta_1 - e_thet1
LE_theta_2_W = LE_theta_2 - e_thet2
LE_theta_3_W = LE_theta_3 - e_thet3

# %% [markdown]
# Creates the equations of motion for Theta 2 and Theta 3

# %%
### THIS SOLVES THE EQUATIONS OF MOTION FOR THETA 2 AND THETA 3

'''   
NOTE:
This solves the EOMs for theta 2 and theta 3 so that they are independent of each other. This will put the other variables (that I have data for) in the equations.
'''

sols = simplify(solve([ (LE_theta_2_W), (LE_theta_3_W)], (alpha_2, alpha_3),
                    simplify=false, rational=False))

# %%
## Separates the solutions of the equation 
ddtheta_2_for_solve = sols[alpha_2]
ddtheta_3_for_solve = sols[alpha_3]

# %% [markdown]
# Creates the functions from the EOMS of theta 2 and Theta 3

# %%
### Lamdifying the new functions
''' this creates functions out of the LE_theta_2 (the angular acceleratiomn of the knee joint) and the LE_theta_3 ( the angular acceleration of the ankle)

'''
### Theta 2
ddtheta_2_for_solve_f = dz3dt =  lambdify([t, m_2, k_B, k_C, b_B, psi_B, l_3, b_C, psi_C, m_3, l_2, g, l_1, theta_1,theta_2,theta_3, omega_1, omega_2, omega_3, a, alpha_1] ,ddtheta_2_for_solve,'numpy')

### Theta 3
ddtheta_3_for_solve_f = dz4dt = lambdify([t, m_2, k_B, k_C, b_B, psi_B, l_3, b_C, psi_C, m_3, l_2, g, l_1,theta_1,theta_2,theta_3,omega_1,omega_2,omega_3,a,alpha_1] ,ddtheta_3_for_solve,'numpy')

# %% [markdown]
# Creates the needed data for the solver

# %%
## Time setup per stage

t_Swing = df_Swing.iloc[:,0]

t_HeelStrike = df_HeelStrike.iloc[:,0]

t_FootPlant = df_FootPlant.iloc[:,0]

t_ToePushOff = df_ToePushOff.iloc[:,0]


## funntions needed for the state space

omega_2_for_solver = lambdify(omega_2,omega_2,'numpy')
omega_3_for_solver = lambdify(omega_3,omega_3,'numpy')


## counter

count_for_solver = lambdify(count,count,'numpy')

# %% [markdown]
# THE SOLVERS!!

# %%
def DSdt(S, t, m_1, m_2, m_3, b_C , l_1, l_2, l_3, k_B, k_C, b_B, psi_B,psi_C, phi_D, g):

    counted, Y_val, z1, the1, z2, the2, z3, the3, z4 = S  #NEEDS TO EXTRACT NUMERIC VALUES and will be filled in from the data
    
        # The last two will be from the data  



## Just pulling the rate of change from the table doesn't seem to work perhaps its a data pull issue? play get data from a wider range and pulg it in 

    # keeps track of the count
    counted = int(counted)
    counter = 1
    

    ## the knee angle
    om2 = omega_2_for_solver(z3)
    alph2 = ddtheta_2_for_solve_f(t, m_2, k_B, k_C, b_B, psi_B, l_3, b_C, psi_C, m_3, l_2, g, l_1, the1, the2, the3, z1, z2, z3, df_Swing.iloc[counted,2], df_Swing.iloc[counted,5])

    ## the ankle angle
    om3 = omega_3_for_solver(z4)
    alph3 = ddtheta_3_for_solve_f(t, m_2, k_B, k_C, b_B, psi_B, l_3, b_C, psi_C, m_3, l_2, g, l_1, the1, the2, the3, z1, z2, z3, df_Swing.iloc[counted,2],df_Swing.iloc[counted,5])
    

    ## Print for debugging

    return[
        counter, # The way to keep track of the row count
        df_Swing.iloc[int(counted),2],  # velocity of y to be added to the position of A, this will be called from data
        df_Swing.iloc[int(counted),3],   # Acceleration of y to be added to the Velocity of A, this will be called from data
        df_Swing.iloc[int(counted),5],   # Omega of theta 1, to be added to the angle of theta 1, this will be called from data
        df_Swing.iloc[int(counted),6], # Alpha of theta 1, to be added to the omega of theta 1, this will be called from data
        om2,   # Omega of theta 2, to be added to the angle of theta 2, this will be calculated
        alph2, # Alpha of theta 2, to be added to the omega of theta 2, this will be calculated
        om3,   # Omega of theta 3, to be added to the angle of theta 3, this will be calculated
        alph3, # Alpha of theta 3, to be added to the omega of theta 3, this will be calculated
    ]

# %%
## ODE swing solver
m_1 = 30
m_2 = 10
m_3 = 5
l_1 = 18
l_2 = 10
l_3 = 6
l_4 = 2
k_B = 2500
k_c = 37
b_B = 3
c_B = 3
psi_B = -50
psi_C = -70
phi_D = 30
k_C = 2150
b_C = 255
g = 32.2

ans_Swing = odeint(DSdt, t = t_Swing, y0 = [0  , df_Swing.iloc[0,1],  df_Swing.iloc[0,2] ,   df_Swing.iloc[0,4] ,df_Swing.iloc[0,5] , -54.1 ,0 ,37.2 , 0], args=( m_1, m_2, m_3, b_C , l_1, l_2, l_3, k_B, k_C, b_B, psi_B,psi_C, phi_D, g))
# Out:
# C:\Users\natha\AppData\Local\Temp\ipykernel_33208\2345424267.py:20: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   ans_Swing = odeint(DSdt, t = t_Swing, y0 = [0  , df_Swing.iloc[0,1],  df_Swing.iloc[0,2] ,   df_Swing.iloc[0,4] ,df_Swing.iloc[0,5] , -54.1 ,0 ,37.2 , 0], args=( m_1, m_2, m_3, b_C , l_1, l_2, l_3, k_B, k_C, b_B, psi_B,psi_C, phi_D, g))

# %%
## ODE heel strike solver
m_1 = 30
m_2 = 10
m_3 = 5
l_1 = 18
l_2 = 10
l_3 = 6
l_4 = 2
k_B = 5000
k_c = 37
b_B = 3
c_B = 3
psi_B = 45
psi_C = -70
phi_D = 30
k_C = 2150
b_C = 255
g = 32.2

ans_HeelStrike = odeint(DSdt, t = t_HeelStrike, y0 = [0  , df_HeelStrike.iloc[0,1],  df_HeelStrike.iloc[0,2] ,   df_HeelStrike.iloc[0,4] ,df_HeelStrike.iloc[0,5] , -.5 ,0 ,13 , 0], args=( m_1, m_2, m_3, b_C , l_1, l_2, l_3, k_B, k_C, b_B, psi_B,psi_C, phi_D, g))

# %%
## ODE foot plant solver
m_1 = 30
m_2 = 10
m_3 = 5
l_1 = 18
l_2 = 10
l_3 = 6
l_4 = 2
k_B = 5000
k_c = 37
b_B = 3
c_B = 3
psi_B = 45
psi_C = -70
phi_D = 30
k_C = 2150
b_C = 255
g = 32.2

ans_FootPlant = odeint(DSdt, t = t_FootPlant, y0 = [0  , df_FootPlant.iloc[0,1],  df_FootPlant.iloc[0,2] ,   df_FootPlant.iloc[0,4] ,df_FootPlant.iloc[0,5] , -3 ,0 ,70 , 0], args=( m_1, m_2, m_3, b_C , l_1, l_2, l_3, k_B, k_C, b_B, psi_B,psi_C, phi_D, g))

# %%
## ODE Toe Push off solver
m_1 = 30
m_2 = 10
m_3 = 5
l_1 = 18
l_2 = 10
l_3 = 6
l_4 = 2
k_B = 5000
k_c = 37
b_B = 3
c_B = 3
psi_B = 45
psi_C = -70
phi_D = 30
k_C = 2150
b_C = 255
g = 32.2

ans_ToePushOff = odeint(DSdt, t = t_ToePushOff, y0 = [0  , df_ToePushOff.iloc[0,1],  df_ToePushOff.iloc[0,2] ,   df_ToePushOff.iloc[0,4] , df_ToePushOff.iloc[0,5] , -44 ,0 , 4 , 0], args=( m_1, m_2, m_3, b_C , l_1, l_2, l_3, k_B, k_C, b_B, psi_B,psi_C, phi_D, g))

# %% [markdown]
# Creates x and Y coordinates for each phase by using "The Coordinator"

# %%
def coordinator(t, y, theta1, theta2 , theta3, l1 , l2 , l3 , l4 ):
    print(theta1)
    return [
        #A coordinates
        0*y, # A_x
        y, #A_y

        #B coordinates
        l1*np.sin(np.deg2rad(theta1)),   #B_x
        y - l1*np.cos(np.deg2rad(theta1)),   #B_y
        

        #C coordinates
        l2*np.sin(np.deg2rad(theta2)) + l1*np.sin(np.deg2rad(theta1)),   #C_x
        y -l1*np.cos(np.deg2rad(theta1)) - l2*np.cos(np.deg2rad(theta2)) ,   #C_y 

        #D coordinates
        l3*np.sin(np.deg2rad(theta3)) + l2*np.sin(np.deg2rad(theta2)) + l1*np.sin(np.deg2rad(theta1)),   #D_x
        y -l1*np.cos(np.deg2rad(theta1)) - l2*np.cos(np.deg2rad(theta2)) - l3*np.cos(np.deg2rad(theta3)),  #D_y    

        #E coordinates
        l4*np.sin(np.deg2rad(phi_D - theta3)) + l2*np.sin(np.deg2rad(theta2)) + l1*np.sin(np.deg2rad(theta1)),   #E_x
        y -l1*np.cos(np.deg2rad(theta1)) - l2*np.cos(np.deg2rad(theta2)) - l4*np.cos(np.deg2rad( phi_D- theta3)),   #E_y  

    ]

# %%
## Swing phase

A_x_Swing, A_y_Swing, B_x_Swing, B_y_Swing, C_x_Swing, C_y_Swing, D_x_Swing, D_y_Swing, E_x_Swing, E_y_Swing   = coordinator(t_Swing, df_Swing.iloc[:,1], df_Swing.iloc[:,4], ans_Swing[:,5],ans_Swing[:,7], 18, 15 , 6 , 3  )
# Out:
# 0    -12.287070
# 1     -9.663365
# 2     -6.986897
# 3     -4.311443
# 4     -1.769453
# 5      0.548400
# 6      2.647610
# 7      4.594430
# 8      6.447870
# 9      8.223520
# 10     9.883430
# 11    11.335600
# 12    12.457200
# 13    13.147200
# 14    13.411200
# 15    13.459700
# 16    13.644300
# 17    14.111900
# 18    14.558400
# 19    14.497100
# 20    13.727600
# Name: Theta 1, dtype: float64

# %%
## Heel Strike Phase

A_x_HS, A_y_HS, B_x_HS, B_y_HS, C_x_HS, C_y_HS, D_x_HS, D_y_HS, E_x_HS, E_y_HS   = coordinator(t_HeelStrike, df_HeelStrike.iloc[:,1], df_HeelStrike.iloc[:,4], ans_HeelStrike[:,5],ans_HeelStrike[:,7], 18, 15 , 6 , 3  )
# Out:
# 0     14.67860
# 1     15.30960
# 2     15.38990
# 3     14.70220
# 4     13.42930
# 5     11.91280
# 6     10.36340
# 7      8.78654
# 8      7.11473
# 9      5.36500
# 10     3.63872
# 11     1.98154
# Name: Heel StrikeTheta 1, dtype: float64

# %%
## Foot plant phase

A_x_FP, A_y_FP, B_x_FP, B_y_FP, C_x_FP, C_y_FP, D_x_FP, D_y_FP, E_x_FP, E_y_FP   = coordinator(t_FootPlant, df_FootPlant.iloc[:,1], df_FootPlant.iloc[:,4], ans_FootPlant[:,5],ans_FootPlant[:,7], 18, 15 , 6 , 3  )

D_y_FP[:] = 0
E_y_FP[:] = 0
# Out:
# 0     13.732500
# 1     12.456200
# 2     11.025000
# 3      9.571140
# 4      8.028810
# 5      6.366670
# 6      4.652240
# 7      2.954700
# 8      1.310250
# 9     -0.237511
# 10    -1.627426
# 11    -2.795110
# 12    -3.711583
# 13    -4.458701
# 14    -5.199351
# 15    -6.032284
# 16    -6.970349
# 17    -8.018099
# 18    -9.139273
# 19   -10.233810
# 20   -11.242230
# 21   -12.198550
# 22   -13.157070
# 23   -14.118740
# 24   -15.050700
# 25   -15.950820
# Name: Foot Plant theta 1, dtype: float64

# %%
## Toe Push Off phase

A_x_TPO, A_y_TPO, B_x_TPO, B_y_TPO, C_x_TPO, C_y_TPO, D_x_TPO, D_y_TPO, E_x_TPO, E_y_TPO   = coordinator(t_FootPlant, df_ToePushOff.iloc[:,1], df_ToePushOff.iloc[:,4], ans_ToePushOff[:,5],ans_ToePushOff[:,7], 18, 15 , 6 , 3  )
# Out:
# 0   -17.335170
# 1   -17.877780
# 2   -18.468510
# 3   -18.401500
# 4   -17.404200
# 5   -14.998680
# 6   -12.233650
# 7    -8.961708
# Name: Toe Push off Theta 1, dtype: float64

# %% [markdown]
# ANIMATORS!!!

# %%
## Animates the swing
def animate_Swing(i):
    ln1.set_data([A_x_Swing[i], B_x_Swing[i], C_x_Swing[i], D_x_Swing[i], E_x_Swing[i]] ,  [A_y_Swing[i], B_y_Swing[i] ,   C_y_Swing[i], D_y_Swing[i], E_y_Swing[i]])
fig, ax = plt.subplots(1,1, figsize=(8,8))
ax.set_facecolor('k')
ax.get_xaxis().set_ticks([])    # enable this to hide x axis ticks
ax.get_yaxis().set_ticks([])    # enable this to hide y axis ticks
ln1, = plt.plot([], [], 'ro--', lw=3, markersize=8)
ln2, = plt.plot([], [], 'ro--', lw=3, markersize=8)
ax.set_ylim(-40,100)
ax.set_xlim(-60,60)
ani = animation.FuncAnimation(fig, animate_Swing, frames=18, interval=17, blit=False)
ani.save('pen.gif',writer='pillow',fps=10)
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img73596f2b63e44cf8afbbdfc517713504">
#   <div class="anim-controls">
#     <input id="_anim_slider73596f2b63e44cf8afbbdfc517713504" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim73596f2b63e44cf8afbbdfc517713504.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim73596f2b63e44cf8afbbdfc517713504.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim73596f2b63e44cf8afbbdfc517713504.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim73596f2b63e44cf8afbbdfc517713504.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim73596f2b63e44cf8afbbdfc517713504.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim73596f2b63e44cf8afbbdfc517713504.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim73596f2b63e44cf8afbbdfc517713504.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim73596f2b63e44cf8afbbdfc517713504.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim73596f2b63e44cf8afbbdfc517713504.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim73596f2b63e44cf8afbbdfc517713504.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select73596f2b63e44cf8afbbdfc517713504"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_73596f2b63e44cf8afbbdfc517713504"
#              >
#       <label for="_anim_radio1_73596f2b63e44cf8afbbdfc517713504">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_73596f2b63e44cf8afbbdfc517713504"
#              checked>
#       <label for="_anim_radio2_73596f2b63e44cf8afbbdfc517713504">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_73596f2b63e44cf8afbbdfc517713504"
#              >
#       <label for="_anim_radio3_73596f2b63e44cf8afbbdfc517713504">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img73596f2b63e44cf8afbbdfc517713504";
#     var slider_id = "_anim_slider73596f2b63e44cf8afbbdfc517713504";
#     var loop_select_id = "_anim_loop_select73596f2b63e44cf8afbbdfc517713504";
#     var frames = new Array(18);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjEsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvc2/+5QAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQAAG1tJR

# %%
## Animates the Foot Plant
def animate_FootPlant(i):
    ln1.set_data([A_x_FP[i], B_x_FP[i], C_x_FP[i], D_x_FP[i], E_x_FP[i]] ,  [A_y_FP[i], B_y_FP[i] ,   C_y_FP[i], D_y_FP[i], E_y_FP[i]])
    
fig, ax = plt.subplots(1,1, figsize=(8,8))
ax.set_facecolor('k')
ax.get_xaxis().set_ticks([])    # enable this to hide x axis ticks
ax.get_yaxis().set_ticks([])    # enable this to hide y axis ticks
ln1, = plt.plot([], [], 'ro--', lw=3, markersize=8)
ln2, = plt.plot([], [], 'ro--', lw=3, markersize=8)
ax.set_ylim(-40,100)
ax.set_xlim(-60,60)
ani = animation.FuncAnimation(fig, animate_FootPlant, frames=18, interval=200, blit=False)
ani.save('pen.gif',writer='pillow',fps=10)
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img267ddd1a105d4ae4beeac9cfc0c3db0e">
#   <div class="anim-controls">
#     <input id="_anim_slider267ddd1a105d4ae4beeac9cfc0c3db0e" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim267ddd1a105d4ae4beeac9cfc0c3db0e.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim267ddd1a105d4ae4beeac9cfc0c3db0e.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim267ddd1a105d4ae4beeac9cfc0c3db0e.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim267ddd1a105d4ae4beeac9cfc0c3db0e.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim267ddd1a105d4ae4beeac9cfc0c3db0e.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim267ddd1a105d4ae4beeac9cfc0c3db0e.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim267ddd1a105d4ae4beeac9cfc0c3db0e.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim267ddd1a105d4ae4beeac9cfc0c3db0e.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim267ddd1a105d4ae4beeac9cfc0c3db0e.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim267ddd1a105d4ae4beeac9cfc0c3db0e.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select267ddd1a105d4ae4beeac9cfc0c3db0e"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_267ddd1a105d4ae4beeac9cfc0c3db0e"
#              >
#       <label for="_anim_radio1_267ddd1a105d4ae4beeac9cfc0c3db0e">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_267ddd1a105d4ae4beeac9cfc0c3db0e"
#              checked>
#       <label for="_anim_radio2_267ddd1a105d4ae4beeac9cfc0c3db0e">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_267ddd1a105d4ae4beeac9cfc0c3db0e"
#              >
#       <label for="_anim_radio3_267ddd1a105d4ae4beeac9cfc0c3db0e">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img267ddd1a105d4ae4beeac9cfc0c3db0e";
#     var slider_id = "_anim_slider267ddd1a105d4ae4beeac9cfc0c3db0e";
#     var loop_select_id = "_anim_loop_select267ddd1a105d4ae4beeac9cfc0c3db0e";
#     var frames = new Array(18);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjEsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvc2/+5QAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQAAGkBJR

# %%
## Animates the Heel Strike
def animate_HeelStrike(i):
    ln1.set_data([A_x_HS[i], B_x_HS[i], C_x_HS[i], D_x_HS[i], E_x_HS[i]] ,  [A_y_HS[i], B_y_HS[i] ,   C_y_HS[i], D_y_HS[i], E_y_HS[i]])
    
fig, ax = plt.subplots(1,1, figsize=(8,8))
ax.set_facecolor('k')
ax.get_xaxis().set_ticks([])    # enable this to hide x axis ticks
ax.get_yaxis().set_ticks([])    # enable this to hide y axis ticks
ln1, = plt.plot([], [], 'ro--', lw=3, markersize=8)
ln2, = plt.plot([], [], 'ro--', lw=3, markersize=8)
ax.set_ylim(-40,100)
ax.set_xlim(-60,60)
ani = animation.FuncAnimation(fig, animate_HeelStrike, frames=10, interval=10, blit=False)
ani.save('pen.gif',writer='pillow',fps=10)
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img64a6a6e3d9e04270a676a33bcfc6a603">
#   <div class="anim-controls">
#     <input id="_anim_slider64a6a6e3d9e04270a676a33bcfc6a603" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim64a6a6e3d9e04270a676a33bcfc6a603.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim64a6a6e3d9e04270a676a33bcfc6a603.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim64a6a6e3d9e04270a676a33bcfc6a603.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim64a6a6e3d9e04270a676a33bcfc6a603.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim64a6a6e3d9e04270a676a33bcfc6a603.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim64a6a6e3d9e04270a676a33bcfc6a603.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim64a6a6e3d9e04270a676a33bcfc6a603.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim64a6a6e3d9e04270a676a33bcfc6a603.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim64a6a6e3d9e04270a676a33bcfc6a603.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim64a6a6e3d9e04270a676a33bcfc6a603.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select64a6a6e3d9e04270a676a33bcfc6a603"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_64a6a6e3d9e04270a676a33bcfc6a603"
#              >
#       <label for="_anim_radio1_64a6a6e3d9e04270a676a33bcfc6a603">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_64a6a6e3d9e04270a676a33bcfc6a603"
#              checked>
#       <label for="_anim_radio2_64a6a6e3d9e04270a676a33bcfc6a603">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_64a6a6e3d9e04270a676a33bcfc6a603"
#              >
#       <label for="_anim_radio3_64a6a6e3d9e04270a676a33bcfc6a603">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img64a6a6e3d9e04270a676a33bcfc6a603";
#     var slider_id = "_anim_slider64a6a6e3d9e04270a676a33bcfc6a603";
#     var loop_select_id = "_anim_loop_select64a6a6e3d9e04270a676a33bcfc6a603";
#     var frames = new Array(10);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjEsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvc2/+5QAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQAAGXlJR

# %%
## Animates the Toe Push Off
def animate_ToePushOff(i):
    ln1.set_data([A_x_TPO[i], B_x_TPO[i], C_x_TPO[i], D_x_TPO[i], E_x_TPO[i]] ,  [A_y_TPO[i], B_y_TPO[i] ,   C_y_TPO[i], D_y_TPO[i], E_y_TPO[i]])
    
fig, ax = plt.subplots(1,1, figsize=(8,8))
ax.set_facecolor('k')
ax.get_xaxis().set_ticks([])    # enable this to hide x axis ticks
ax.get_yaxis().set_ticks([])    # enable this to hide y axis ticks
ln1, = plt.plot([], [], 'ro--', lw=3, markersize=8)
ln2, = plt.plot([], [], 'ro--', lw=3, markersize=8)
ax.set_ylim(-40,100)
ax.set_xlim(-60,60)
ani = animation.FuncAnimation(fig, animate_ToePushOff, frames=8, interval=9, blit=False)
ani.save('pen.gif',writer='pillow',fps=10)
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img42de1527fc274b73bfc2a84b7b04f031">
#   <div class="anim-controls">
#     <input id="_anim_slider42de1527fc274b73bfc2a84b7b04f031" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim42de1527fc274b73bfc2a84b7b04f031.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim42de1527fc274b73bfc2a84b7b04f031.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim42de1527fc274b73bfc2a84b7b04f031.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim42de1527fc274b73bfc2a84b7b04f031.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim42de1527fc274b73bfc2a84b7b04f031.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim42de1527fc274b73bfc2a84b7b04f031.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim42de1527fc274b73bfc2a84b7b04f031.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim42de1527fc274b73bfc2a84b7b04f031.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim42de1527fc274b73bfc2a84b7b04f031.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim42de1527fc274b73bfc2a84b7b04f031.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select42de1527fc274b73bfc2a84b7b04f031"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_42de1527fc274b73bfc2a84b7b04f031"
#              >
#       <label for="_anim_radio1_42de1527fc274b73bfc2a84b7b04f031">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_42de1527fc274b73bfc2a84b7b04f031"
#              checked>
#       <label for="_anim_radio2_42de1527fc274b73bfc2a84b7b04f031">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_42de1527fc274b73bfc2a84b7b04f031"
#              >
#       <label for="_anim_radio3_42de1527fc274b73bfc2a84b7b04f031">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img42de1527fc274b73bfc2a84b7b04f031";
#     var slider_id = "_anim_slider42de1527fc274b73bfc2a84b7b04f031";
#     var loop_select_id = "_anim_loop_select42de1527fc274b73bfc2a84b7b04f031";
#     var frames = new Array(8);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjEsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvc2/+5QAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQAAGypJRE

# %% [markdown]
# NON HOLONOMIC

# %%
const_HS_y_E = y_E
const_HS_u_E = u_E + vel_W

# %%
### Creating Non Holonomic for Hs
A_HS = [0, -u_B, -(u_C-u_B), -(u_E-u_C)]
symbols_HS = [y, theta_1, theta_2, theta_3]
dsymbols_HS = [v_A, omega_1, omega_2, omega_3]


NH_HS_equations =[0,0,0,0,0]

for better in range (0,np.size(NH_HS_equations)):
    
    NH_HS_equations[better] = simplify(diff(diff(T, dsymbols_FP[better]), t) - diff(T, symbols_FP[better]) + diff(D, dsymbols_FP[better]) + diff(V, symbols_FP[better])
                                       
    + lam_FP_1*diff(const_FP_y_E,symbols_FP[better]) + lam_FP_2*diff(const_FP_y_D,symbols_FP[better]) + lam_FP_3*diff(const_FP_u_E,symbols_FP[better]) + lam_FP_4*diff(const_FP_u_D,symbols_FP[better]))
